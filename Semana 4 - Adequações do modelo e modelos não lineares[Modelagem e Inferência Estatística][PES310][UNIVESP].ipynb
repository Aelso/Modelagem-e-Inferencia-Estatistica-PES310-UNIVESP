# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Modelagem e Inferência Estatística** 💻
# ###**Link**:https://ava.univesp.br/ultra/courses/_5842_1/cl/outline
# ##**Profa. Drª. Victoria Alejandra Salazar Herrera**💪
# ##**Aluno: Aelso Rocha Brito**👷
# ##**notebook**ComAnotaçõesDasVideoaulas✍
# ## **Semestre:** 01.2022
# ---

# %% [markdown]
# # **4|Adequações do modelo e modelos não lineares**🔰

# %% [markdown]
# Nesta semana, você vai aprender a verificar se o modelo linear usado para ajustar os dados é adequado usando algumas ferramentas gráficas com foco nos resíduos e nos resíduos padronizados. Caso essa ferramenta indique que seu modelo não é adequado, é necessário verificar as opções de modelos que podem ser usados, assim, serão introduzidos mais alguns modelos conhecidos como intrinsicamente lineares, os quais são modelos não lineares em que foram aplicadas transformações que permitem estudá-los como se fossem o modelo linear. Após a transformação de variáveis, isto é, a linearização, é importante voltar para o modelo inicial.

# %% [markdown]
# ### **Habilidades e competências:**🖖
#
# 🏆 Lembrar o conceito de não linearidade;
#
# 🏆 Entender os processos de padronização de resíduos;
#
# 🏆 Aplicar a transformação de variáveis a modelos não lineares;
#
# 🏆 Entender as formas de análise de modelos não lineares de uma variável;
#
# 🏆 Usar software para aplicar regressão linear a conjuntos de dados.

# %% [markdown]
# ### **Semana 4 - Revisitando conhecimentos**✍
#
# 📼**Videoaula – Matemática - Aula 11 - Gráficos das funções exponencial e logaritmo**🚀
#
# ☑https://youtu.be/5Ze5c0NBVLs💻
#
# Videoaula do professor Claudio Possani, na qual são apresentadas as funções exponencial e logarítmica e seus respectivos gráficos.
#
# 📼**Videoaula – O que é função potência?**🚀
#
# ☑https://youtu.be/HVwyw_Q7DBg💻
#
# Videoaula do professor Helio Tosatti, na qual é apresentado como identificar uma função potência e o esboço do seu gráfico característico.

# %% [markdown]
# ##**Videoaula 9 - Adequação dos modelos e modelos não lineares** 📚
#
# ####📑PDF:https://ava.univesp.br/bbcswebdav/xid-6935300_1;
#
# ####🎬Videoaula No YT:https://youtu.be/wtOYM6YQUzs;
# ---

# %% [markdown]
# **O QUE VOU APRENDER HOJE?** &#9888;
#
# Verificar a adequabilidade do modelo
# * Resíduos e resíduos padronizados
#
# Gráficos de diagnóstico
#
# Modelos não lineares
#
# Regressão com variáveis transformadas

# %% [markdown]
# **VERIFICAR A ADEQUABILIDADE DO MODELO** ♖
#
#  $y=\beta_0 + \beta_1 x + ϵ$
#
# ✔ Linearidade: a relação entre x e y é linear.
#
# ✔ Homoscedasticidade: assume que os resíduos têm variância constante.
#
# ✔ Independência: assume que os termos de erro são independentes.
#
# ✔ Normalidade: assume que os resíduos são normalmente distribuídos.
#
# **`O modelo probabilístico linear se aplica a todo tipo de dados?`**
#
# |$y=$$\beta_0$$+\beta_1x$$ + ϵ$||||
# |-----------------------|--|||
# |[ Y  X ]  ←            |Distibuição de probabilidade|||
# |                       |  n        |(  X,| ß )|
# |                       |  ❘          |    ↓|  ↓|
# |                       | ↓      |(Variáveis preditoras| Parâmetros|
# |                       |Função|☛Linear                    | |
# |                       |      |☛Não-linear                | |
# |                       |      |☛Uma variável              | |
# |                       |      |☛Múltiplas variáveis       | |

# %% [markdown]
# 1. $E(Y_i - \hat{Y}_i) = E(Y_{i})-E(\hat{\beta}_{0}-$$\hat{β_1}X_{i})$
# $E(Y_i - \hat{Y}_i) = {\beta}_{0}+{β_1}X_{i} -({\beta}_{0}+{β_1}X_{i}) = 0$
#
# 2. $V(Y_i - \hat{Y}_i)= \alpha^2.[1-{\frac{1} n} + \frac{({x_i} -{\bar{x}})^ 2} {S_{xx}}]$
# $ e^ *_i =$ $\frac{y_i+\hat{y_{i}}}{S \sqrt{{1+\frac{1} n} + \frac{({x^ *} -{\bar{x}})^ 2} {S_xx}}}$ $ i = 1,...,n$

# %% [markdown]
# **GRÁFICOS DE DIAGNÓSTICO**
#
# Variáveis que devem ser observadas para verificar a validade e utilidade do modelo:
#
# | |Abcissas                  |Ordenadas                |Representação   |
# |-|--------------------------|-------------------------|----------------|
# | |Eixo horizontal           |Eixo vertical            |                |
# |1|x (variável preditora)    |$e^*$ ou e               |(x, $e^*$)      |
# |2|$\hat{y}$(dados previstos) |$e^*$ ou e               |($\hat{y}$,$e^*$)|
# |3|y (dados observados)      |$\hat{y}$(dados previstos)|($\hat{y}$,$y$)  |
# |4|Gráfico de probabilidade normal de $e^*$|              |                |

# %% [markdown]
# **EXPECTATIVA VS. REALIDADE**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Os dados nem sempre têm um comportamento linear

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dados não lineares
#
# Fonte: (DEVORE, 2018, p. 510)

# %% [markdown]
# 2. Variância de Y depende de x

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Variância não constante
#
# Fonte: (DEVORE, 2018, p. 510)

# %% [markdown]
# ✔ Método de mínimos quadrados ordinário considera $σ^2$ constante.
#
# ✔ $β_0$ e  $β_1 $ são estimados atribuindo os mesmos pesos a cada ( $x_i$, $y_i$
# ).
#
# ✔ Se a variância de Y depende de x, então V($Y_i$ ) ≠  $σ^2 $ 🡪 não é constante.
#
# ✔ Atribuir pesos: Se V( $Y_i$) aumenta com x:
#
# * Peso menor para  $Y_i$ resultante de x grande.
#
# * Peso maior para $Y_i$ resultante de x pequeno.
#
# ✔ Mínimos quadrados ponderados V($Y_i$) =$kx^2_i$
#  🡪 $wi=\frac{1} {X^2_i}$

# %% [markdown]
# 3. Outliers podem afetar a reta ajustada

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Retas diferentes, com e sem outliers.
# Fonte: (DEVORE, 2018, p. 510)

# %% [markdown]
# 4. ε não tem distribuição normal $Y=\beta_0 + \beta_1 x + ϵ$
# 5. Se i denota dependência do tempo $ε_i$
#  depende do tempo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dados dependentes do tempo.
# Fonte: (DEVORE, 2018, p. 510)

# %% [markdown]
# 6. Uma ou mais variáveis podem ter sido omitidas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Variáveis preditoras omitidas
# Fonte: (DEVORE, 2018, p. 510)

# %% [markdown]
# **O QUE É UM MODELO NÃO-LINEAR**
#
# Vídeo do Prof. André definindo um modelo não-linear

# %% [markdown]
# **REGRESSÃO COM VARIÁVEIS TRANSFORMADAS**
#
# Funções intrinsecamente lineares

# %% [markdown]
# Tabela 13.1 Funções intrinsecamente lineares úteis*

# %% [markdown]
# |Função                                     |Transformação para linearizar |Forma linear                      |
# |-------------------------------------------|------------------------------|----------------------------------|
# |Exponencial $y= \alpha e^{βx}$             | $y^{'}=ln(y)$                | $y^{'} =ln(\alpha)+\beta x$|
# |🐕🐕🐕🐕🐕🐕🐕🐕🐕|🐙🐙🐙🐙|🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩                                      |                              |                                  |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fonte: (DEVORE, 2018, p. 515)

# %% [markdown]
# |Função                                     |Transformação para linearizar |Forma linear                      |
# |-------------------------------------------|------------------------------|----------------------------------|
# |b. Potência $y=αx^ β$                      |$y^{'} =log(y),x^{'} =log(x)$ | $y^{'} =log(\alpha)+\beta x^{'}$ |
# |🐕🐕🐕🐕🐕🐕🐕🐕🐕|🐙🐙🐙🐙|🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩                                      |                              |                                  |
#
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fonte: (DEVORE, 2018, p. 515)

# %% [markdown]
# |Função                                     |Transformação para linearizar |Forma linear                      |
# |-------------------------------------------|------------------------------|----------------------------------|
# |c.  $y=α + β$ x $log(x)$                     |$x^{'} =log(x)$               | $y^{'} =\alpha+\beta x^{'}$      |
# |🐕🐕🐕🐕🐕🐕🐕🐕🐕|🐙🐙🐙🐙|🦩🦩🦩🦩🦩🦩🦩🦩                                      |                              |                                  |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fonte: (DEVORE, 2018, p. 515)

# %% [markdown]
# |Função                                     |Transformação para linearizar |Forma linear                      |
# |-------------------------------------------|------------------------------|----------------------------------|
# |d. Recíproca $y=\alpha + \beta.\frac{1}{x}$|$x^{'} =\frac{1}{x}$          | $y^{'} =\alpha+\beta x^{'}$      |
# |🐕🐕🐕🐕🐕🐕🐕🐕🐕|🐙🐙🐙🐙|🦩🦩🦩🦩🦩🦩🦩🦩                                      |                              |                                  |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fonte: (DEVORE, 2018, p. 515)

# %% [markdown]
# $ \hat{\beta}_1 ={\frac{{Σx_{i}^ ´y_{i}^ ´ - Σx_{i}^ ´y_{i}^ ´/n}} {{Σ(x_{i}^ ´)^2 - Σ(x_{i}^ ´)^2/n}}}$
#
# $ \hat{\beta}_0 ={\frac{{Σy_i^ ´ - \hat{\beta}_1Σx_i^ ´}} {{n}}}$ = $\bar{y}^ ´ - \hat{\beta}_1 \bar{x}^ ´$

# %% [markdown]
# **MODELAGEM E INFERÊNCIA ESTATÍSTICA**
#
# Adequações do modelo e modelos não lineares

# %% [markdown]
# ##**Videoaula 10 - Adequação dos modelos e modelos não lineares Exemplos** 📚
#
# ####📑PDF:https://ava.univesp.br/bbcswebdav/xid-6935501_1;
#
# ####💽Google Colab:https://ava.univesp.br/bbcswebdav/xid-6743618_1;
#
# ####🎬Videoaula No YT:https://youtu.be/VEKzmq6yUgI;
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
from statsmodels.graphics.gofplots import ProbPlot
plt.style.use('seaborn')
plt.rc('axes', titlesize=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **O QUE VOU APRENDER HOJE?**
#
# Exemplos práticos
#
# Adequação do Modelo
#
# Modelo intrinsecamente linear

# %% [markdown]
# **ADEQUAÇÃO DO MODELO: EXEMPLO 1**
#
# Dados sobre x = taxa de liberação na área do queimador e y = emissões de NOx. Observe os dados e os valores ajustados, os resíduos e os resíduos
# padronizados. A reta de regressão estimada é $y = –45,55 + 1,71x$ e $r^2 = 0,961$.

# %%
lstx2 = (100, 125, 125, 150, 150, 200, 200, 250, 250, 300, 300, 350, 400, 400)
lsty2 = (150, 140, 180, 210, 190, 320, 280, 400, 430, 440, 390, 600, 610, 670)
# Construir o DataFrame e nomear as colunas
df = pd.DataFrame(list(zip(lstx2, lsty2)),
                  columns =["x","y"])
x=df ['x']
y=df ['y']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#adicionar uma constante preditora
x = sm.add_constant(x)
#fit linear regression model
modelo = sm.OLS(y, x).fit() #atenção esta variável será usada no IC
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     294.7
# Date:                Fri, 22 Apr 2022   Prob (F-statistic):           8.23e-10
# Time:                        01:03:18   Log-Likelihood:                -69.243
# No. Observations:                  14   AIC:                             142.5
# Df Residuals:                      12   BIC:                             143.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -45.5519     25.468     -1.789      0.099    -101.041       9.938
# ...

# %%
# parâmetros da reta
b=modelo.params
b0=b[0] #intercepto
b1=b[1] #inclinação
print('y= {0}{1} x'.format(b0,b1))
# Out:
# y= -45.5519053876479351.7114323258869912 x

# %%
y_pred=list(modelo.predict())
#sns.resid(modelo)
resi=list(modelo.resid)

# %%
#crear instancia influence
influence = modelo.get_influence()
#obter residuos standardizados
stdresid = list(influence.resid_studentized_internal)

# %%
prop=np.divide(resi,stdresid) #e/e* para verificar a proporcionalidade entre o erro e o erro padronizado

# %%
#@title Tabela geral
dft = pd.DataFrame(list(zip(lstx2, lsty2, y_pred, resi, stdresid, prop)),
               columns =["x","y","yc","e","e*","e/e*"])
dft

# %% [markdown]
# e* não é múltiplo de e devido ao fato de que as variâncias residuais são diferentes umas das outras.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ADEQUAÇÃO DO MODELO: EXEMPLO 2**
#
# Base de dados GT Auto

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7e177410-de26-48c8-931d-d51f35928cd5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e177410-de26-48c8-931d-d51f35928cd5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving carst.csv to carst (1).csv

# %%
#Observar os dados
import io
#import pandas as pd
df = pd.read_csv(io.StringIO(uploaded['carst.csv'].decode('utf-8')))
df.head(30)
# Out:
#                          brand/model/year  cap_vol  consumo  power  weight  \
# 0                   Gurgel BR800 0.8 1991      792     12.0     33     650
# 1                  FIAT UNO Mille EP 1996      994     10.4     58     870
# 2                 Hyundai HB20 Sense 2020     1000     12.8     80     989
# 3                    FIAT Strada 1.4 2016     1368     10.3     86    1084
# 4                 VolksWagen GOL 1.6 2015     1598     10.5    104     961
# 5            Chevrolet Cruze LTZ 1.8 2016     1796      8.5    144    1427
# 6                    Honda Civic EXR 2016     1997      9.5    155    1294
# 7                 Ford Focus 2.0 GLX 2012     1999      9.2    148    1347
# 8                       BMW 325i 3.0 2012     2996      6.5    218    1460
# 9                 AUDI A4 3.2 V6 Fsi 2011     3197      7.1    269    1610
# 10      Mercedes-Benz CLS 350 3.5 V6 2012     3498      6.6    306    1735
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ADEQUAÇÃO DO MODELO: EXEMPLO 2**
#
# Base de dados GT Auto 🡪 Motor aspirado

# %%
df1 = df[df.Etype != 1]
df1.head(15)
# Out:
#                      brand/model/year  cap_vol  consumo  power  weight  cemm  \
# 0               Gurgel BR800 0.8 1991      792     12.0     33     650  34.4
# 1              FIAT UNO Mille EP 1996      994     10.4     58     870  18.6
# 2             Hyundai HB20 Sense 2020     1000     12.8     80     989  14.5
# 3                FIAT Strada 1.4 2016     1368     10.3     86    1084  12.5
# 4             VolksWagen GOL 1.6 2015     1598     10.5    104     961   9.8
# 5        Chevrolet Cruze LTZ 1.8 2016     1796      8.5    144    1427  10.2
# 6                Honda Civic EXR 2016     1997      9.5    155    1294  10.9
# 7             Ford Focus 2.0 GLX 2012     1999      9.2    148    1347  10.4
# 8                   BMW 325i 3.0 2012     2996      6.5    218    1460   7.1
# 9             AUDI A4 3.2 V6 Fsi 2011     3197      7.1    269    1610   6.4
# 10  Mercedes-Benz CLS 350 3.5 V6 2012     3498      6.6    306    1735   6.1
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Reta de regressão**

# %%
#adicionar uma constante preditora
x = sm.add_constant(x)
#fit linear regression model
modelo = sm.OLS(y, x).fit() #atenção esta variável será usada no IC
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     294.7
# Date:                Fri, 22 Apr 2022   Prob (F-statistic):           8.23e-10
# Time:                        01:18:50   Log-Likelihood:                -69.243
# No. Observations:                  14   AIC:                             142.5
# Df Residuals:                      12   BIC:                             143.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -45.5519     25.468     -1.789      0.099    -101.041       9.938
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# parâmetros da reta
b=modelo.params
b0=b[0] #intercepto
b1=b[1] #inclinação
print('y= {0}{1} x'.format(b0,b1))
# Out:
# y= -45.5519053876479351.7114323258869912 x

# %% [markdown]
# **Resíduos e resíduos padronizados**

# %% [markdown]
# $y= 11,9686 - 001259x$
#
# $x$ = Capacidade volumétrica
#
# $y$= Consumo

# %% [markdown]
# $x$ = Capacidade volumétrica
#
# $y$= Consumo
#
# $\hat{y}$= Valores previsto de y
#
# $ϵ$ = Resíduos
#
# $ϵ^*$ = Resíduos padronizadas . $ϵ/ϵ^*$ : proporção

# %% [markdown]
# **Gráficos de diagnóstico**

# %%
sns.lmplot(x='cap_vol', y='consumo',hue='Etype', data=df);plt.grid(True)

# %% [markdown]
# 1. Reta de regressão e valores observados

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Valores previstos vs. valores observados

# %%
#@title Gráficos de diagnóstico 1 (y vs. x)
sns.lmplot(x='cap_vol', y='consumo', data=df1);plt.grid(True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Resíduos padronizados vs. x

# %%
#@title Gráficos de diagnóstico 3 (resíduos padronizados vs. x)
sns.scatterplot(x='x', y='e*', data=dft);plt.grid(True)
plt.xlabel('x= Capacidade Volumétrica')
plt.ylabel('e*= Resíduos padronizados')
plt.axhline(y=0, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Resíduos padronizados vs. y

# %%
#@title Gráficos de diagnóstico 4 (resíduos padronizados vs. y)
sns.scatterplot(x='y', y='e*', data=dft);plt.grid(True)
plt.xlabel('y= Consumo')
plt.ylabel('e*= Resíduos padronizados')
plt.axhline(y=0, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Gráfico de probabilidade normal

# %%
#@title Gráficos de diagnóstico 5 Probabilidade Normal
QQ = ProbPlot(influence.resid_studentized_internal)
plot_lm_2 = QQ.qqplot(line='45', alpha=0.5, color='#4C72B0', lw=1)
plot_lm_2.axes[0].set_xlabel('Percentil')
plot_lm_2.axes[0].set_ylabel('Resíduos padronizados')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **MODELO INTRINSECAMENTE LINEAR: EXEMPLO 3**
#
# Nenhum aficionado por batatas fritas gosta que elas fiquem encharcadas, por isso é importante encontrar características do processo de produção que as permitam ter uma textura atraente.
#
# Os seguintes dados em que x = tempo de fritura (s) e y = teor de umidade (%) apareceram no artigo “Thermal and Physical Properties of Tortilla Chips as a Function of Frying Time” (J. of Food Processing and Preservation, 1995: 175–189). A partir destes dados:

# %%
 x = (5, 10, 15, 20, 25, 30, 45, 60)
 y= (16.3, 9.7, 8.1, 4.2, 3.4, 2.9, 1.9, 1.3)

# %% [markdown]
# a. Construa um gráfico de dispersão de y versus x e comente.
#
# b. Construa um gráfico de dispersão dos pares (ln(x), ln(y)) e comente.
#
# c. Qual é a relação probabilística entre x e y sugerido pelo padrão linear no gráfico da parte (b)?
#
# d. Preveja o valor do teor de umidade ao fritar as batatas por 20s, de uma forma
# que transmita informações sobre confiabilidade e precisão.
#
# e. Analise os resíduos do ajuste do modelo de regressão linear para os dados
# transformados e comente.

# %% [markdown]
# **a. Construa um gráfico de dispersão de y versus x e comente.**
#
# Os dados podem ser descritos mediante uma reta?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Confira a observação com o procedimento de regressão linear

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# b. Construa um gráfico de dispersão dos pares (ln(x), ln(y)) e comente.
#
# Observe os valores das variáveis transformadas.

# %%
dfries2 = pd.DataFrame(list(zip(x, y, vtx, vty)),
               columns =["x","y","ln_x","ln_y"])
dfries2.head()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Observe os valores das variáveis transformadas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# c. Qual é a relação probabilística entre x e y sugerido pelo padrão linear
# no gráfico da parte (b)?

# %% [markdown]
# |Função                                     |Transformação para linearizar |Forma linear                      |
# |-------------------------------------------|------------------------------|----------------------------------|
# |b. Potência $y=αx^ β$                      |$y^{'} =log(y),x^{'} =log(x)$ | $y^{'} =log(\alpha)+\beta x^{'}$ |
# |🐕🐕🐕🐕🐕🐕🐕🐕🐕|🐙🐙🐙🐙|🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩                                      |                              |                                  |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fonte: (DEVORE, 2018, p. 515)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **d) Preveja o valor do teor de umidade ao fritar as batatas por 20s, de forma que transmita informações sobre confiabilidade e precisão.**
#
# Considerar o procedimento dos mínimos quadrados, mas aplicar às variáveis transformadas para obter a reta:

# %% [markdown]
# |Forma linear                                                       |
# |-------------------------------------------------------------------|
# | $y^{'} =log(\alpha)+\beta x^{'} ou y^{'} =ln(\alpha)+\beta x^{'}$ |
# |🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩                                                       |

# %% [markdown]
# Depois, aplicar as transformações necessárias para
# obter a função potência.

# %% [markdown]
# |Função                                     |
# |-------------------------------------------|
# | Potência $y=αx^ β$                      |
# |🐕🐕🐕🐕🐕🐕🐕    |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Resultado inicial:

# %% [markdown]
# |Forma linear                                                       |
# |-------------------------------------------------------------------|
# | $y^{'} =ln(\alpha)+\beta x^{'}$ |
# | $y^{'} =4,6384 + 1,0492x^{'}$ |
# |🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩

# %% [markdown]
# Voltando para as variáveis originais:

# %% [markdown]
# |Função                                     |
# |-------------------------------------------|
# |$y=αx^ β$                      |
# | $ln(\alpha) = 4,6384$  $\beta= -1,0492$|
# |  $\alpha = \epsilon ^{4,6384}$|
# | $\alpha = 103,3788$|
# |$y=103,3788^{-1,0492}$|
# |🐕🐕🐕🐕🐕🐕🐕🐕🐕|

# %% [markdown]
# Para x=20s quanto vale y?

# %% [markdown]
# |Forma linear                                                       |
# |-------------------------------------------------------------------|
# | $y^{'} =4,6384 + 1,0492x^{'}$ |
# | $y^{'} = ln(20) = 2,9957$ |
# |$y^{'} =4,6384 + 1,0492x^{'}$|
# |$y^{'} =4,6384 + 1,0492(2,9957)$|
# |$y^{'} =1,4953$|
# |$par(2,9957, 1,4953)$|
# |🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩|

# %% [markdown]
# |Função Potência                                                     |
# |-------------------------------------------------------------------|
# | $y^{'} =4,6384 + 1,0492x^{-1,0492}$ |
# | $y^{'} =4,6384 + 1,0492(20)^{-1,0492}$ |
# | $y^{'} =4,461$ |
# |$par(20, 4,461)$|
# |🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩         |

# %% [markdown]
# Esta informação é suficiente para ter noção de confiabilidade e precisão?

# %% [markdown]
# Para x=20s, quanto vale y?
# A equação do IP:

# %% [markdown]
# $\hat{y} ± t_{\frac{α} 2,n-2}*\sqrt{{S^ 2} + S^ 2_\hat{Y}}$

# %% [markdown]
# Necessário calcular:

# %% [markdown]
# $\hat{y} ± t_{\frac{α} 2,n-2}, s^2$ e $S_{\hat{y}}^2$

# %% [markdown]
# $\hat{α}^2 = s^2 = \frac{SQE}{n-2} = \frac{Σ(y_i-\hat{y_i})^2}{n-2}$

# %% [markdown]
# |Forma linear                                                       |
# |-------------------------------------------------------------------|
# | $y^{'} =4,6384 + 1,0492x^{'}$ |
# |$par(2,9957, 1,4953)$|
# |🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩|

# %% [markdown]
# |Função Potência                                                     |
# |-------------------------------------------------------------------|
# | $y^{'} =4,6384 + 1,0492x^{-1,0492}$ |
# |$par(20, 4,461)$|
# |🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩         |

# %% [markdown]
# $S_{\hat{Y}}= S\sqrt{(\frac{1}{n}+\frac{({x^ *- \hat{x}}^2)}{S_{xx}})}$

# %% [markdown]
# Necessário calcular:

# %% [markdown]
# $t_{\frac{α} 2,n-2}=2,4469$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#usar a tabela tstudent pata t
from scipy.stats import t
alpha = 0.05  # nível de significia = 5% 
df = len(x) - 2 # gl (n - 2)                                     
v = t.ppf(1 - alpha/2, df) 
print(f't=: {v}')
# Out:
# t=: 2.4469118487916806

# %%
x=dfries['x']
y=dfries['y']
vtx=np.log(x)
vty=np.log(y)
y_pred=list(modelo.predict())
#sns.resid(modelo)
resi=(modelo.resid)
#SQE = residuos ao quadrado
sqe=np.sum(resi*resi) 
gl=modelo.df_resid  #gl=n-2
s2=sqe/gl
s=pow(s2,1/2)
sqe,s2,s
# Out:
# (0.1259894484543931, 0.02099824140906552, 0.14490769961967348)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para x=20s, quanto vale y?

# %% [markdown]
# |Forma linear                                                       |
# |-------------------------------------------------------------------|
# | $y^{'} =4,6384 + 1,0492x^{'}$ |
# |$par(2,9957, 1,4953)$|
# |🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩|

# %% [markdown]
# |Função Potência                                                     |
# |-------------------------------------------------------------------|
# | $y^{'} =4,6384 + 1,0492x^{-1,0492}$ |
# |$par(20, 4,461)$|
# |🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩         |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Para x=20s, quanto vale y?**
#
# A equação do IP:

# %% [markdown]
# $\hat{y^{'}} ± t_{\frac{α} 2,n-2}*\sqrt{{S^ 2} + S^ 2_\hat{Y}}$

# %% [markdown]
# $\hat{y^{'}} ± t_{\frac{α} 2,n-2}*\sqrt{{S^ 2} + S^ 2_\hat{Y}}= 2,9957±(2,4469)\sqrt{0,020998-0,51253^2}$

# %% [markdown]
# IP:
#
# $\hat{Y^{'}}=(1,119196,1,871399)$
#
# $1,119196<\hat{Y^{'}}<1,871399$

# %% [markdown]
# |Forma linear                                                       |
# |-------------------------------------------------------------------|
# | $y^{'} =4,6384 + 1,0492x^{'}$ |
# |$par(2,9957, 1,4953)$|
# |🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩|

# %% [markdown]
# Voltando para as variáveis originais:
#
# IP:
#
# $\hat{Y^{'}}=(3,062392,6,497386)$
#
# $3,062392<\hat{Y^{'}}<6,497386$

# %% [markdown]
# |Função Potência                                                     |
# |-------------------------------------------------------------------|
# | $y^{'} =4,6384 + 1,0492x^{-1,0492}$ |
# |$par(20, 4,461)$|
# |🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩🦩         |

# %% [markdown]
# **e) Analise os resíduos do ajuste do modelo de regressão linear para os dados transformados e comente.**
#
# Para as variáveis transformadas $ln(x)$ e $ln(y)$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **[Texto-base – Probabilidade e estatística para engenharia e ciências (Leia as páginas 506 a 519) | Jay. L. Devore](https://integrada.minhabiblioteca.com.br/reader/books/9788522128044/pageid/518)** ☕
#
# Não se esqueça de que, para acessar este livro, você antes precisa fazer o login na plataforma desta biblioteca.
# ☑https://login.univesp.br/simplesaml/module.php/core/mb.php

# %% [markdown]
# **[Material-base – Modelos lineares generalizados](https://lamfo-unb.github.io/2018/09/29/MLG/)** ☕
#
# Não se esqueça de que, para acessar este livro, você antes precisa fazer o login na plataforma desta biblioteca.
# ☑https://login.univesp.br/simplesaml/module.php/core/mb.php

# %% [markdown]
# ### **Semana 4 - Aprofundando o tema**✍
#
#
# [Material de apoio – Animações GeoGebra para funções exponencial e logarítmica](https://www.geogebra.org/m/NwaefQKz)
#
# Animação com duas funções, exponencial e logarítmica, aproveite para interagir mudando valores dos parâmetros de cada função.
#
#
# [Material de apoio –  Animações GeoGebra para função potência ](https://www.geogebra.org/m/rCnefWPS)
#
# Animação da função potência, aproveite para interagir mudando valores dos parâmetros da função.

# %% [markdown]
# ### 💊**Semana 4 - Aprofundando o tema**  ❗
# 🔗https://ava.univesp.br/webapps/blackboard/content/launchLink.jsp?course_id=_5842_1&content_id=_767416_1&mode=view

# %% [markdown]
# ##**Semana 4 - Exercício de apoio**🤾  🏃 🏋
# ---
# ☑https://ava.univesp.br/bbcswebdav/xid-6745442_1
#
# ---

# %% [markdown]
# ###**Semana 4 - Atividade Avaliativa**🤾  🏃 🏋
# ---
#
# ☑https://ava.univesp.br/ultra/courses/_5842_1/cl/outline
#
# ---

# %% [markdown]
# ### 💊**Semana 4 - Fórum de dúvidas** 🕵
# 🔗https://ava.univesp.br/webapps/blackboard/content/launchLink.jsp?course_id=_5842_1&content_id=_759191_1&mode=view

# %% [markdown]
# ## **Em síntese - Semana 4**🏆 🚀
#
# Nesta semana, você aprendeu a verificar se o modelo linear é adequado para um determinado conjunto de dados usando alguns cálculos, como os resíduos padronizados e ferramentas gráficas, considerando, além das variáveis observadas, algumas relações com as variáveis esperadas e os resíduos.
#
# Também aprendeu um procedimento simples de linearização dos modelos: exponencial, potência, recíproco e logarítmico, mediante uma mudança de variáveis para trabalhar com esses modelos como se fossem lineares, por esse motivo eles são conhecidos como modelos intrinsicamente lineares.
#
# **Finalmente, leia na sequência a lista de objetivos de aprendizagem e selecione aqueles que você conseguiu atingir:**
#
# 🧯 Lembrei o conceito de não linearidade;
#
# 🧯 Entendi os processos de padronização de resíduos;
#
# 🧯 Apliquei a transformação de variáveis a modelos não lineares;
#
# 🧯 Entendi as formas de análise de modelos não lineares de uma variável;
#
# 🧯 Usei software para aplicar regressão linear a conjuntos de dados.
