# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Modelagem e Inferência Estatística** 💻
# ###**Link**:https://ava.univesp.br/ultra/courses/_5842_1/cl/outline
# ##**Profa. Drª. Victoria Alejandra Salazar Herrera**💪
# ##**Aluno: Aelso Rocha Brito**👷
# ##**notebook**ComAnotaçõesDasVideoaulas✍
# ## **Semestre:** 01.2022
# ---

# %% [markdown]
# ##**Semana 1 - Atividade Avaliativa**🤾  🏃 🏋
# ---
#
# ☑https://ava.univesp.br/webapps/blackboard/content/launchLink.jsp?course_id=_5842_1&content_id=_759150_1&mode=view
#
# ---
#
# **PERGUNTA 1**
#
# Considerando a definição e objetivo da regressão linear, isto é, o tipo de dados aos quais ela se aplica, como estes dados são chamados, e o tipo de relação que existe entre estes dados, leia as alternativas e escolha a que define corretamente o que é regressão.
#
# ☑**A regressão visa investigar a relação entre duas variáveis, sendo pelo menos uma delas aleatória, mediante o uso de uma relação determinística. negrito**
#
# A regressao visa investigar a relacao entre duas variáveis determinısticas, mediante o uso de uma relacao determinıstica.
#
# A regressão visa investigar a relação entre duas variáveis aleatórias, mediante o uso de uma relação aleatória.
#
#  A regressão visa investigar a relação entre duas variáveis aleatórias, mediante uma função de distribuição de probabilidade.
#
# A regressão visa investigar a relação entre duas variáveis quaisquer, mediante o uso de uma relação aleatória.

# %% [markdown]
# **`Comentário da resposta`**:
#
# Quando se fala em regressão é importante que você entenda que pelo menos a variável Y, isto é, a variável de resposta, é
# aleatória. A variável X, ou preditora, pode de alguma forma ser controlada pelo pesquisador, mas, eventualmente, pode ser  também uma vari ável aleatória. Apenas para esclarecer, um modelo determinístico se caracteriza por ter sempre a mesma resposta (Y) para uma determinada entrada (X). Quando se trata do estudo de dados (ou variáveis) aleatórios, adotamos o nome de modelo estocástico.
#
# ----------------

# %% [markdown]
# **PERGUNTA 2**
#
# Considere duas variáveis que para valores entre 6 e 21 estão relacionadas mediante reta de regressão verdadeira $y = -0,15 +0,092x$
# Considerando duas amostras pontuais de em que x vale 12 e 18, se a variância for 0,025. Realize os procedimentos para verificar a probabilidade de Y ultrapassar 0,1706 para cada amostra.
# Tendo todos seus resultados, confira eles com o que se afirma a seguir:
#
# O valor esperado para $x=18$ é $μ_{Y:18} = -0,1656$ O valor esperado para $x=12$ é $μ_{Y:12} = -0,2484$
#
# A probabilidade $P(Y > 0,1706)$ para $x=12$ é $P(Y > 0,1706) = 0,009$  para $x=12$ é $P(Y > 0,1706) = 0,4207$
#
# Após verificar com seus cálculos, é correto o que se afirma em:
#
#  Apenas II e III são corretas.
#
# Apenas I e III são corretas.
#
# ☑ **Apenas IV é correta.**
#
# Apenas I e II são corretas.
#
# Apenas I, II e III são corretas.

# %% [markdown]
# **`Comentário da resposta:`**
#
# A resposta correta é a IV é correta, isto é A probabilidade $P(Y > 0,1706)$ para $x=12$ é $P(Y > 0,1706) = 0,4207$
#
# a) O valor esperado de Y pode ser calculado mediante a seguinte expressão $x=18$ é $μ_{Y:x^ *} = -0,15 +0,092x$
#
# Para x=12
#
# $μ_{Y:12} = -0,15 +0,092(12)$
#
# Portanto $μ_{Y:12} = -0,1605$
#
# Portanto a afirmativa II é incorreta.
#
# Para x=18
#
# $μ_{Y:18} = -0,15 +0,092(18)$
#
# Portanto $μ_{Y:18}$
#
# $μ_{Y:18} = -0,2484$
#
#
# Portanto a afirmativa I é incorreta.
#
# b) para x=12 qual a probablidade de Y ultrapasar 0,170
#
# $P(Y > 0,1706) = P(Z >\frac{0,1706 -0,1605}{0,025})$
#
# $P(Y > 0,1706) = P(Z >0,20)$
#
# $P(Y > 0,1706) = 1 - 𝜽 (0,20)$
#
# Da tabela Z da distribuição normal $ 𝜽 (0,20) = 0,5793$
#
# $P(Y > 0,1706) = 1 - 0,5793$
#
# $P(Y > 0,1706) = 0,4207$
#
# Esta reposta valida a afirmativa VI invalidando a afirmativa III.
#
# ------

# %% [markdown]
# **PERGUNTA 3**
#
# Existem algumas ferramentas gráficas para analisar amostras. Uma das mais usadas é o diagrama de dispersão ou gráfico de dispersão. Observe o seguinte diagrama de dispersão, conforme os dados apresentados nele, é possível afirmar que:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#
# Os dados apresentam uma correlação positiva.
#
# Há maior quantidade de amostras que apresentam valores da variável preditora no intervalo que $ 37< x < 47 $
#
# ☑**Há menor quantidade de amostras que apresentam valores da variável resposta no intervalo**  $x>9,3$
#
# Há menor quantidade de amostras que apresentam valores da variável preditora intervalo $y < 17$
#
# Há maior quantidade de amostras que apresentam valores da variável resposta no intervalo $7,5 < y < 7,9$

# %% [markdown]
# **`Comentário da resposta:	`**
#
# No diagrama de dispersão a variável preditora varia de 7 a 10 e a variável resposta varia de 0 a 70 aproximadamente.
#
# Também pode-se observar que para a variável preditora, existem 6 intervalos marcados, a concentração de dados é quase uniforme nos quatro primeiros, tendo três a quatro dados em cada um, nos últimos intervalos observam-se menos dados, sendo o último intervalo, definido por valores maiores a 9,3 no eixo x, quem apresenta menores amostras (apenas 1), observe que esta-se referindo à variável resposta apesar de marcar seu intervalo usando os valores de x (variável preditora).
#
# No caso da variável resposta  as amostras estão distribuídas de forma mais aleatória, considerando também seis intervalos sendo o intervalo definido por 27 > y > 37 onde tem menos amostras de x (apenas 1). DE forma similar, os intervalos para observar a variável preditora estão definidos pelos valores em y (variável resposta).
#
# -----

# %% [markdown]
# **PERGUNTA 4**
#
# Após estudar os modelos de regressão linear simples e o modelo probabilístico linear, existem algumas diferenças importantes entre os elementos destes modelos, já que alguns deles representam o conjunto de dados e os outros definem o comportamento desses dados numa reta.
# Considerando estas informações, leia as seguintes afirmativas e escolha a que apresenta as informações corretas.
#
# $β_0 , β_1$ e $ϵ $ são parâmetros do modelo de regressão linear simples.
#
# ☑**$β_0 , β_1$	são parâmetros do modelo de regressão linear simples.**
#
# $x$ e $y$ são parâmetros do modelo de regressão linear simples e do probabilístico.
#
# $β_0 , β_1$ , $ϵ$, $x$ e $y$ são parâmetros do modelo de regressão linear probabilístico.
#
# $β_0 , β_1$  e $x$ e $y$ são parâmetros do modelo de regressão linear simples.

# %% [markdown]
# **`Comentário da resposta:`**
#
# Um erro muito comum é confundir os elementos do modelo, mantenha sempre em mente que as variáveis são x e y, as ditas variáveis são os dados aos quais o pesquisador ou o cientista de dados tem acesso, sendo simplista são os pares de pontos da amostra.
# Os parâmetros são os valores obtidos mediante o processo de regressão para permite Um erro muito comum é confundir os elementos do modelo, mantenha sempre em mente que as variáveis são x e y, as ditas variáveis são os dados aos quais o pesquisador ou o cientista de dados tem acesso, sendo simplista são os pares de pontos da amostra.
# Os parâmetros são os valores obtidos mediante o processo de regressão para permitir descrever a relação entre as variáveis, usando termos não técnicos, são os valores de $\beta_{0}$ e $\beta_{1}$ que se procura quantificar para obter assim uma reta de regressão linear simples, no caso do modelo linear probabilístico além de $\beta_{0}$ e $\beta_{1}$ considera-se também o $\epsilon$. ir descrever a relação entre as variáveis, usando termos não técnicos, são os valores de $\beta_{0}$ e $\beta_{1}$ que se procura quantificar para obter assim uma reta de regressão linear simples, no caso do modelo linear probabilístico além de $\beta_{0}$ e $\beta_{1}$ considera-se também o $\epsilon$.
#
# --------------
