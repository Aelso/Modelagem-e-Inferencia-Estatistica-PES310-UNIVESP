# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Modelagem e Inferência Estatística** 💻
# ###**Link**:https://ava.univesp.br/ultra/courses/_5842_1/cl/outline
# ##**Profa. Drª. Victoria Alejandra Salazar Herrera**💪
# ##**Aluno: Aelso Rocha Brito**👷
# ##**notebook**ComAnotaçõesDasVideoaulas✍
# ## **Semestre:** 01.2022
# ---

# %% [markdown]
# **PERGUNTA 1** ⛽
#
# Um conjunto de dados foi analisado e forneceu o resultado que se apresenta na imagem, em que os valores da coluna coef representam o parâmetro ($\beta_i$) correspondente a cada variável e os valores da coluna std err representam o erro padrão de cada parâmetro.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Considerando que esse resultado corresponde a um modelo de primeira ordem com interação, leia as seguintes afirmativas e verifique mediante cálculos extras as informações fornecidas:
#
# I. O modelo correspondente é $y=17,2787 - 6,3678x_1 -3,6584x_2 +1,7067x_3$ em que $x_3=x_1 x_2$.
#
# II. Para $x_1=x_2=x_3=1$ o valor esperado de y será $\mu_{y.1,1,1}=8,9592$.
#
# III. O valor do desvio-padrão de $\beta_2$ indica que o parâmetro $\beta_2$ é predominante no modelo.
#
# IV. Com os dados fornecidos é possível calcular intervalos de confiança para cada parâmetro $\beta_i$ apenas se tiver o valor do $t_{\frac{\alpha}{2} ,n - (k +1)}$
#
# V. Com os dados fornecidos é possível realizar o teste de utilidade do modelo.
#
# Após ler e verificar as informações das afirmativas, é correto o que se afirma em:
# apenas I e IV.
#
# apenas II, III e V.
#
# **apenas I, II e IV.** 🧂
#
# apenas I, II, III e V.
#
# apenas II e IV.

# %% [markdown]
# **Comentário da resposta:**
#
# De acordo com os dados fornecidos na imagem, apenas algumas afirmativas podem ser validadas:
#
# **Afirmativa I**. Correta O modelo correspondente é $y=17,2787-6,3678x_1 - 3,6584x_2 + 1,7067x_3$ em que $x_3=x_1x_2$. O termo $x_3=x_1x_2$ é correto devido a ser um modelo com interação.
#
# **Afirmativa II**. Correta Para $x_1=x_2=x_3=1$ o valor esperado de $y$ será
# $\mu_{y.1,1,1}=8,9592$
#
# $\mu_{y.1,1,1}=17,2787 - 6,3678x_1 - 3,6584x_2 + 1,7067x_3$
#
# $\mu_{y.1,1,1}=17,2787-6,3678(1)-3,6584(1)+1,7067(1)=8,9592$
#
# **Afirmativa III**. Incorreta Os desvios-padrão não indicam se a variável tem maior ou menor influência no modelo, apenas estão relacionados com quanto os valores do $\beta_i$ podem variar quando realizado o processo de regressão.
#
# **Afirmativa IV**. Correta Com os dados fornecidos é possível calcular intervalos de confiança para cada parâmetro \beta_i apenas se tiver o valor do $t_{\frac{\alpha}{2},n -(k+1)}$. Como está se falando em intervalo de confiança do parâmetro é correto considerar o valor do t-student.
#
# **Afirmativa V**. Incorreta Com os dados fornecidos não é possível realizar o teste de utilidade do modelo, pois no caso de modelos com variáveis múltiplas é necessário calcular f, e para esse objetivo, além do valor de k, é necessário ter os valores de $SQE$, $SQT$, $R^2$ e $n$. Ditos valores não estão disponíveis no resultado.

# %% [markdown]
# **PERGUNTA 2** 🔥
#
# Um conjunto de $10$ amostras e $k=3$ foi ajustado mediante o modelo de regressão múltipla. Com os dados foi calculado um $SQE=234$ e um $SQT=375$.
# Com esses dados, obtenha o coeficiente de regressão múltipla ajustado,
#
#
# $R_a=0,967$
#
# $R_a=-0,967$
#
# **$R_a^2=0,936$**🐸
#
# $R_a^2=-0,936$
#
# $R_a^2=2,404$

# %% [markdown]
# **Comentário da resposta:**
#
# O coeficiente de determinação múltipla ajustado pode ser calculado mediante a seguinte equação:
#
# $R_a^2=\frac{n - 1 }{n - ( k + 1 )} \frac{SQE}{SQT}$
#
# Substituindo os valores:
# $R_a^2=\frac{10-1}{10-(3+1)}\frac{234}{375}=0,936$

# %% [markdown]
# **PERGUNTA 3** 🐖
#
# Para todos os modelos de regressão é necessário realizar procedimentos de verificação da validade dos parâmetros obtidos ou dos valores previstos. Nesse sentido é necessário realizar os testes de hipótese (que validam ou rejeitam os valores dos parâmetros e a utilidade do modelo).
# No procedimento de teste de hipótese considera-se o cálculo de valores críticos e estatísticas de teste.
#
# Com essas informações em mente, na regressão de variáveis múltiplas o teste de utilidade do modelo considera o cálculo de:
#
# $f=\frac{\frac{R^2}{k}}{(1-R^2)[n-(k +1)]}$ e verificar se $f≥F_{critic}$
#
# $t_{\frac{\alpha}{2},n-( k +1)}$ e verificar se $t ≥t_{critic}$ lembrando que t se deve aplicar a $\beta_i$
#
# $t_{\frac{\alpha}{2},n-( k +1)}$ e verificar se $t ≥t_{critic}$ lembrando que t se deve aplicar a $\beta_1$
#
# $t_{\frac{\alpha}{2},n-( k +1)}$ e verificar se $t ≥t_{critic}$
#
# $f=\frac{\frac{R^2}{k}}{(1-R^2)[n-(k +1)]}$ e verificar se $f≥F_{critic}$ 😎

# %% [markdown]
# **Comentário da resposta:**
#
# Quando o modelo é de variáveis múltiplas, o cálculo do teste de utilidade do modelo deve ser realizado usando a distribuição F. A estatística de teste será calculada mediante $f=\frac{\frac{R^2}{k}}{(1-R^2)[n-(k+1)]}$ e o valor $F_{crit}$ deve ser obtido da tabela F, considerando $F_{k,n-(k+1)}$ finalmente verificar se $f ≥ F_{crit}$ e rejeitar a hipótese nula se a relação se cumpre.
#
# Em contraparte, para o cálculo dos intervalos de confiança, previsão e valores esperados ainda deve usar a distribuição t-student.

# %% [markdown]
# **PERGUNTA 4** 🐪
#
# Considerando duas variáveis preditoras e uma variável resposta, existem os seguintes modelos de variáveis múltiplas:
#
# I. O modelo de primeira ordem: $Y=\beta_0 +\beta_1 x_1 +\beta_2 x_2 +ϵ$.
#
# II. O modelo de segunda ordem sem interação:
# $Y=\beta_0 +\beta_1 x_1 +\beta_2 x_2 +\beta_3 x_1 x_2 + ϵ$.
#
# III. O modelo com preditores de primeira ordem e interação: $Y=\beta_0 +\beta_1 x_1 +\beta_2 x_2 +\beta_3 x_1^2 +\beta_4 x_2^2 +\epsilon$.
# O modelo completo de segunda ordem ou modelo quadrático completo:
# $Y=\beta_0 +\beta_1 x_1 +\beta_2 x_2 +\beta_3 x_1^2 +\beta_4 x_2^2 +\beta_5 x_1 x_2 +ϵ$.
#
# V. O modelo regressão múltipla geral: $Y=\beta_0 +\beta_1 x_1 +\beta_2 x_2 +ϵ$ obtido fazendo $k=2$.
#
# Após observar as afirmativas, é correto o que se afirma em:
#
# apenas I, II, III e IV.
#
# **apenas I, IV e V.** 🐳
#
# apenas II e III.
#
# apenas I e IV.
#
# apenas II, III e V.

# %% [markdown]
# **Comentário da resposta:**
#
# Considerando duas variáveis preditoras e uma variável resposta, pode-se considerar que:
#
# 1. O modelo de primeira ordem: $Y=\beta_0+\beta_1x_1+\beta_2x_2+\epsilon$.
# 2. O modelo de segunda ordem sem interação:
# $Y=\beta_0+\beta_1x_1+ beta_2x_2+\beta_3x_1^2+\beta_4x_2^2+\epsilon$.
# 3. O modelo com preditores de primeira ordem e interação: $Y=\beta_0 + \beta_1 x_1+\beta_2x_2+\beta_3x_1x_2+\epsilon$.
# 4. O modelo completo de segunda ordem ou modelo quadrático completo:
# $Y=\beta_0+\beta_1x_1+\beta_2x_2+\beta_3x_1^2+\beta_4x_2^2+\beta_5x_1x_2+\epsilon$.
# 5. O modelo regressão múltipla geral: $Y=\beta_0+\beta_1x_1+\beta_2x_2+... +\beta_kx_k+\epsilon$, se $k=2$ o modelo se reduz a $Y=\beta_0+\beta_1x_1+\beta_2x_2+\epsilon$.

# %% [markdown]
# **PERGUNTA 5** 🎨
#
# Um conjunto de dados foi ajustado com o seguinte modelo $y=17,2787 - 6,3678 x_1 - 3,6584 x_2 +1,7067 x_3$ se $x_3=120, x_2=0$ e $x_3=450,$ e o erro padrão da reta $s_{\hat{y}}=1,80$.
#
# Calcule o intervalo de confiança do valor esperado de y com um nível de confiança de 95%, considere que para o número de amostras que forneceram dito modelo, e o nível de confiança definido valor de$ t_{\frac{\alpha}{2},n - ( k +1)}=2,201$.
#
#
# $13,5375 <\mu_{y.120,0,450}<21,4611$
#
#
# $17,1577 <\mu_{y.120,0,450}<25,1195$ 🚨
#
#
# $19,3577 <\mu_{y.120,0,450}<22,9577$
#
#
# $12,28577 <\mu_{y.120,0,450}<29,2475$
#
#
# $9,4379 <\mu_{y.120,0,450}<17,3615$

# %% [markdown]
# **Comentário da resposta:**
#
# Inicialmente, calcular o valor esperado, isto é:
# $\mu_{y.120,0,150}$
#
# Sendo que a reta é $y=17,2787-6,3678x_1-3,6584x_2+1,7067x_3$
#
# $\mu_{y.120,0,450}=17,2787-6,3678(120)-3,6584(0)+1,7067(450)$
#
# $\mu_y . 120,0,450  =21,1577$
#
# Se o erro padrão da reta $s_\hat{y}=1,80$ e o $t_{\frac{\alpha}{2},n-(k+1)}=2,201$ foi fornecido no enunciado, resta simplesmente aplicar na fór$\mula:
#
# IC: $ \hat{y} ± t_{\frac{\alpha}{2},n-(k+1)}s_{\hat{y}}$
#
# Substituindo os valores:
# IC:$21,1577±2,201(1,80)$
#
# IC:$17,1577 < \mu_{y.120,0,450} < 25,1195 $

# %% [markdown]
# **PERGUNTA 6** 🐦
#
# Um conjunto de dados foi ajustado com o seguinte modelo $y=17,2787 - 6,3678x_1 - 3,6584x_2 +1,7067x_3$ em que $x_3=x_1 x_2$. Em que a variável $x_2$ é categórica.
#
# Pela característica deste modelo, o parâmetro que acompanha a variável $x_1$, isto é, $\beta_1=-6,3678$. Responda e justifique: se o resto das variáveis se mantiverem constantes, o incremento de $x_1$ em uma unidade significa que y diminui em $6,3678$ unidades?
#
# Sim, se todas as variáveis ficarem fixas, acrescentar $x_1$ em uma unidade faz $y$ diminuir já que $\beta_1$ é negativo.
#
# Sim, visto que $x_2$ é categórica e em alguns casos adota o valor de 0, cancelando, assim, a parte da equação que contém dita variável.
#
# Não, visto que $x_3=x_1 x_2$, a variação de $y$ se obtém somando $\beta_3 +\beta_1$.
#
# Não, visto que $x_2$ é categórica e em alguns casos adota o valor de 0.
#
# **Não, visto que $x_3=x_1 x_2$, não é possível manter $x_3$ fixo se acrescentar o valor de $x_1$ em uma unidade.** 🧛

# %% [markdown]
# **Comentário da resposta:**
#
# Em um modelo linear de primeira ordem **sem interação**, isto é, $x_3$ ser independente de $x_1x_2$ poderia se afirmar ao acrescentar x_1 em uma unidade $y$ diminui em $6,3678$ unidades, porque $\beta_1$ é negativo, se, e somente se, o resto das variáveis se mantiverem fixas. Se $\beta_1$ fosse positivo $y$ iria incrementar em $6,3678$ unidades ao incrementar $x_1$ em uma unidade.
#
# Porém, no modelo analisado é explicitado que $x_3=x_1 x_2$, portanto, não é possível manter fixa a variável $x_3$. Incrementar $x_1$ em uma unidade irá incrementar o valor de $x_3$ inevitavelmente. Dessa forma não se pode inferir em que proporção y diminui apenas com o valor do parâmetro $\beta_1$.

# %% [markdown]
# **PERGUNTA 7** 🍉
#
# Considere o modelo de regressão múltipla a seguir:
# $Y=\beta_0 +\beta_1 x_1 +\beta_2 x_2 +\beta_3 x_1 x_2 +\epsilon$.
#
# Neste modelo a variável $x_1$ representa a velocidade de um carro em km/h e a variável $x_2$ representa se o carro tem motor naturalmente aspirado ($x_2=0$) ou motor turbo ($x_2=1$).
#
# Com isso em mente, observe as seguintes equações e escolha a que representa corretamente essa condição.
#
# Para motor turbo o modelo pode ser descrito como $Y=\beta_0 +\beta_1 x_1 +( \beta_2 +\beta_3 ) x_2 +\epsilon$.
#
# Para motor turbo o modelo pode ser descrito como $Y=\beta_0 +\beta_1 x_1 +\beta_2 x_2 +\beta_3 x_2 +\epsilon$, em que $\beta_2=\beta_3$.
#
# Para motor naturalmente aspirado o modelo pode ser descrito como $Y=\beta_0 +\beta_1 x_2 +\epsilon$.
#
# Para motor naturalmente aspirado o modelo pode ser descrito como $Y=\beta_0 +\beta_3 x_1 x_2 +\epsilon$.
#
# **Para motor turbo o modelo pode ser descrito como $Y=\beta_0 +\beta_2 +( \beta_1 +\beta_3 ) x_1 +\epsilon$.** 🔋

# %% [markdown]
# **Comentário da resposta:**
#
# Considere o modelo de regressão múltipla a seguir:
# $Y=\beta_0+\beta_1x_1+\beta_2x_2+\beta_3x_1x_2+\epsilon.$
#
# Nas condições definidas, o nosso modelo terá dois tipos de comportamento de acordo com a variável categórica.
#
# Para motor turbo $x_2=1$, assim:
#
# $Y=\beta_0+\beta_1x_1+\beta_2(1)+\beta_3x_1(1)+\epsilon$.
#
# Portanto, o modelo pode ser descrito como $Y=\beta_0+\beta_2+(\beta_1+\beta_3)x_1+\epsilon$.
#
# Para motor naturalmente aspirado $x_2=0$, assim:
# $Y=\beta_0 + \beta_1 x_1 + \beta_2 ( 0 ) + \beta_3 x_1 ( 0 ) +  \epsilon$.
#
# Portanto, o modelo pode ser descrito como $Y=\beta_0 + \beta_1 x_1  +  \epsilon$.

# %% [markdown]
# **PERGUNTA 8** 🐎
#
# Um conjunto de dados com três variáveis preditoras foi analisado e forneceu o resultado que se apresenta na imagem, em que os valores da coluna coef representam o parâmetro $(\beta_i)$ correspondente a cada variável, e os valores da coluna std err representam o erro padrão de cada parâmetro.
#
# Para um $t_{\frac{\alpha}{2},n - ( k +1 )}=3,250$ (obtido para esta amostra com um nível de confiança de 90%). Calcule o intervalo de confiança do parâmetro $\beta_2$.
#
# $-13,7428 < \beta_2 < 0,9772$
#
# $-6,0141 < \beta_2 < 40,5714$
#
# $0,3060 < \beta_2 < 3,1074$
#
# $-8,0914 < \beta_2 < 0,7746$ 🐃
#
# $-10,5258 < \beta_2 < 13,2538$

# %% [markdown]
# **Comentário da resposta:**
#
# Da tabela pode-se obter os seguintes dados:
# $\beta_2=-3,6584$ e $s_{\hat{\beta}_2}=1,364$
#
# Como o $t_{\frac{\alpha}{2},n-(k+1)}=3,250$ foi fornecido no enunciado, resta simplesmente aplicar na fórmula:
#
# IC: $\beta_2±t_{\frac{\alpha}{2},n-(k+1)} s_{\hat{\beta}_2}$
#
# Substituindo os valores:
#
# IC: $-3,6584±3,250(1,364)$
#
# IC: $-8,0914< \beta_2 <0,7746$
#
# Observe que a $90\%$ o IC abrange mais valores.
