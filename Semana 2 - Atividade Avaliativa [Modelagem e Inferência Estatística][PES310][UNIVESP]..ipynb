# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Modelagem e Inferência Estatística** 💻
# ###**Link**:https://ava.univesp.br/ultra/courses/_5842_1/cl/outline
# ##**Profa. Drª. Victoria Alejandra Salazar Herrera**💪
# ##**Aluno: Aelso Rocha Brito**👷
# ##**notebook**ComAnotaçõesDasVideoaulas✍
# ## **Semestre:** 01.2022
# ---

# %% [markdown]
# #**Semana 2 - Atividade Avaliativa**🤾  🏃 🏋
# ---
#
# ☑https://ava.univesp.br/webapps/blackboard/content/launchAssessment.jsp?course_id=_5842_1&content_id=_759119_1&mode=view
#
# ---

# %% [markdown]
# **PERGUNTA 1**
#
# Considere a seguinte amostra, na qual se apresenta a relação entre a taxa de eficiência de fosfatização de um peça de aço de acordo com a temperatura.
#
# |Temp.|	76,67   |7,78	|78,33	|78,89	|78,89	|79,44	|80,00	|80,56| 82,22|82,22|82,22 |82,22|
# |---- |---------|-------|-------|-------|-------|-------|-------|-----|------|-----|------|-----|
# |Taxa |	0,84	|1,31	|1,42	|1,03	|1,07	|1,08	|1,04	|1,80 |	1,45 |1,60 |1,61  |2,13 |
# Temp. |	82,22	|82,78	|82,78	|83,33	|83,33	|83,33	|83,33	|84,44|	84,44|85,00|85,56 |86,67|
# |Taxa |	2,15	|0,84	|1,43	|0,90	|1,81	|1,94	|2,68	|1,49 |	2,52 |3,0  |1,87  |3,08 |
#
# Aplique o procedimento de regressão linear para obter a reta que descreve esses dados, considere como variável preditora a Temperatura e como variável resposta a Taxa de eficiência, depois calcule os coeficientes de determinação e indique o que ele representa.

# %% [markdown]
# $Y=-12,23 -0,1697x$ o modelo escolhido é correto para descrever essa amostra.

# %% [markdown]
# $Y=-12,23 -0,1697x$ o modelo escolhido tem o $54,86\%$ de confiabilidade.

# %% [markdown]
# $Y=-14,65 -0,9092x$ o modelo escolhido é correto para descrever essa amostra.

# %% [markdown]
# $r^2 = 0,4514$ o modelo escolhido tem o $57,98\%$ de confiabilidade.

# %% [markdown]
# 🖖 $Y=-12,23 -0,1697x$, $r^2 = 0,4514$ o modelo escolhido pode não ser adequado para descrever essa amostra. 🍺

# %% [markdown]
# 🌌 **Comentário da resposta:** 🏹
#
# Para realizar o procedimento de regressão, inicialmente devem ser calculadas as somatórias $Σ(x_i)$ , $Σ(y_i)$ , $Σ(x_i y_i)$, $Σ(x^2_i)$,$Σ(y^2_i)$
# lembrando que $Y$ é taxa e $x$ é a temperatura.
#
# $Σ(x_i) = 1966,6499$
#
# $Σ(y_i) = 40,0899$
#
# $Σ(x_i y_i) = 3311,5069$
#
# $Σ(x^2_i) = 161310,1817$
#
# $Σ(y^2_i) = 76,8823$
#
# $\bar{x} = 81,9438$
#
# $\bar{y} = 1,67042$
#
# Com esses valores é possível encontrar as relações de $S_{xx}$,$S_{yy}$ e $S_{xy}$, de acordo com o número de dados da amostra n=24.
#
#
# $S_{xx} = Σ _{(x^2_i)} - \frac{(Σ_{(x_i)})^2}{n}= 161310.1817 - \frac{(1966,6499)^2}{24}$
#
# $S_{xx} = 155,5058$
#
# $S_{yy} = Σ _{(y^2_i)} - \frac{(Σ_{(y_i)})^2}{n}= 76,8823 - \frac{(40,0899)^2}{24}$
#
# $S_{yy} = 9,9153$
#
# $S_{xy} = Σ _{(x_iy_i)} - \frac{Σ_{(x_i)}Σ_{(y_i)}}{n}=3311,5069 - \frac{(1966,6499)(40,0899)}{24}$
#
# $S_{xy} = 26,3820$

# %% [markdown]
# Com estes dados é possível calcular os parâmetros do modelo de regressão linear:
#
# $\beta_1 = \frac{S_{xy}}{S_{xx}} = \frac{26,3820}{155,5058}$
#
# $\beta_1 = 0,1697$
#
# $\beta_0 = \bar{y} - \beta_1\bar{x} = 1,67042 - (0,1697)(81,9438)$
#
# $\beta_0 = -12,2354$

# %% [markdown]
# (Observação: os resultados podem mudar de acordo com a quantidade de casas decimais usadas para o cálculo)
#
# Portanto, a reta de regressão para esses dados é $Y=-12,23 +0,1697x$
#
# Agora é necessário calcular o coeficiente de determinação, portanto os valores de SQE e SQT são necessários.
#
# $ SQE = S_{yy} -\hat{β}_1S_{xy}$
#
# $ SQE = 9,9153 -(-0,1697)(26,3820)$
#
# $ SQE = 5,43952$
#
# Da definição, tem-se que Da definição, tem-se que $SQT = S_{yy}$ portanto, $SQT = 9,9153$
#
# Finalmente, $r^2 = 1- \frac{5,43952}{9,9153}$
#
# $r^2 = 0,4514$
#
# Como $r^2 = 0,4514$ ou $45,14\%$ o modelo de regressão linear simples pode não ser adequado para este tipo de amostra.

# %% [markdown]
# **PERGUNTA 2**
#
# Considere a seguinte amostra, na qual se apresenta a relação entre a taxa de eficiência de fosfatização de um peça de aço de acordo com a temperatura
#
# |Temp.|	76,67   |7,78	|78,33	|78,89	|78,89	|79,44	|80,00	|80,56| 82,22|82,22|82,22 |82,22|
# |---- |---------|-------|-------|-------|-------|-------|-------|-----|------|-----|------|-----|
# |Taxa |	0,84	|1,31	|1,42	|1,03	|1,07	|1,08	|1,04	|1,80 |	1,45 |1,60 |1,61  |2,13 |
# Temp. |	82,22	|82,78	|82,78	|83,33	|83,33	|83,33	|83,33	|84,44|	84,44|85,00|85,56 |86,67|
# |Taxa |	2,15	|0,84	|1,43	|0,90	|1,81	|1,94	|2,68	|1,49 |	2,52 |3,0  |1,87  |3,08 |
#
# Aplique o procedimento de regressão linear para obter a reta que descreve esses dados, considere como variável preditora a temperatura e como variável resposta a taxa de eficiência, e calcule o valor esperado de $Y$ para $x= 80$.

# %% [markdown]
# $μ_{y,80} = 0,926$

# %% [markdown]
# $μ_{y,80} = 2,1945$

# %% [markdown]
# $μ_{y,80} = 2,7036$

# %% [markdown]
# $μ_{y,80} = 1,040$

# %% [markdown]
# ☎ $μ_{y,80} = 1,346$ 🛸

# %% [markdown]
# 🍯 **Comentário da resposta:** 🐻
#
# Para realizar o procedimento de regressão, inicialmente devem ser calculadas as somatórias $Σ(x_i)$ , $Σ(y_i)$ , $Σ(x_i y_i)$, $Σ(x^2_i)$,$Σ(y^2_i)$
# lembrando que $Y$ é taxa e $x$ é a temperatura.
#
# $Σ(x_i) = 1966,6499$
#
# $Σ(y_i) = 40,0899$
#
# $Σ(x_i y_i) = 3311,5069$
#
# $Σ(x^2_i) = 161310,1817$
#
# $Σ(y^2_i) = 76,8823$
#
# $\bar{x} = 81,9438$
#
# $\bar{y} = 1,67042$
#
# Com esses valores é possível encontrar as relações de $S_{xx}$,$S_{yy}$ e $S_{xy}$, de acordo com o número de dados da amostra n=24.
#
#
# $S_{xx} = Σ _{(x^2_i)} - \frac{(Σ_{(x_i)})^2}{n}= 161310.1817 - \frac{(1966,6499)^2}{24}$
#
# $S_{xx} = 155,5058$
#
# $S_{yy} = Σ _{(y^2_i)} - \frac{(Σ_{(y_i)})^2}{n}= 76,8823 - \frac{(40,0899)^2}{24}$
#
# $S_{yy} = 9,9153$
#
# $S_{xy} = Σ _{(x_iy_i)} - \frac{Σ_{(x_i)}Σ_{(y_i)}}{n}=3311,5069 - \frac{(1966,6499)(40,0899)}{24}$
#
# $S_{xy} = 26,3820$

# %% [markdown]
# Com estes dados é possível calcular os parâmetros do modelo de regressão linear:
#
# $\beta_1 = \frac{S_{xy}}{S_{xx}} = \frac{26,3820}{155,5058}$
#
# $\beta_1 = 0,1697$
#
# $\beta_0 = \bar{y} - \beta_1\bar{x} = 1,67042 - (0,1697)(81,9438)$
#
# $\beta_0 = -12,2354$
#
# Portanto, a reta de regressão para esses dados é $Y=-12,2354 +0,1697x$
#
# Com essa reta pode ser calculado o valor esperado de Y para $x=80$.
#
# $μ_{y,80} = -12,23 +0,1697(80)$
#
# $μ_{y,80} = 1,346$

# %% [markdown]
# **PERGUNTA 3**
#
# Quando se realiza a análise de regressão para um conjunto n de pares de dados $(x_i,y_i)$se obtém uma reta do tipo $Y=β_0+β_1x$ que descreve a relação que existe entre as variáveis $x$ e $y$.Se a amostra for tomada novamente e realizado um novo processo de regressão linear, é obtida uma reta de regressão também.
#
# Nesse contexto, responda: os valores de $β_0$ e $β_1$ podem adotar valores diferentes dos iniciais? Justifique a sua resposta.

# %% [markdown]
# 👑 **Sim, visto que os pares de dados consideram variáveis aleatórias.** 💥
#
# Sim, visto que os pares de dados consideram variáveis determinísticas.
#
# Sim, visto que os pares de dados não são dependentes do tempo.
#
# Não, visto que os pares de dados descrevem os mesmos fenômenos.
#
# Não, visto que os pares de dados consideram variáveis determinísticas.

# %% [markdown]
# 🛫 **Comentário da resposta:** 👽
#
# 👀 Visto que a variável preditora (Y) é sempre aleatória e a variável preditora (x) pode ser aleatória ou ser de alguma forma definida pelo pesquisador, nunca uma amostra fornecerá um conjunto de dados idêntico, isso ocorreria se as variáveis fossem determinísticas. Visto que as amostras têm essa característica, não adotar sempre o mesmo valor de Y para um determinado valor de x, os parâmetros da reta de regressão apresentam variações. Por este motivo surge um novo termo $s^2$ conhecido como a variança estimada, ela representa a variação do $\beta_1$ quando comparada com o seu valor esperado $\hat{\beta}_1$. 🐪

# %% [markdown]
# **PERGUNTA 4**
#
# Um conjunto de dados fornece os seguintes valores:$S_{xx}=1585,2307$, $S_{yy}=77,2708$ e $S_{xy}=-341,9592$ e uma reta de regressão $Y=9,10099-0,21572x_i$

# %% [markdown]
# Calcule a soma de quadrados dos erros. 🔮
#
# SQE = 0,9546
#
# SQE = 3189,4383
#
# 🦜 **SQE = 3,5048** 📍
#
# SQE = 77,2708
#
# SQE = 0,5645

# %% [markdown]
# 📫**Comentário da resposta:** ☢
#
# Os dados importantes para calcular SQE são: $S_{yy}=77,2708$, $S_{xy}=-341,9592$ e $\beta_1$, sendo que a equação da reta é $Y=9,10099-0,21572x_i$ o valor de $\beta_1 = -0,21572$ ✋
#
# $SQE = S_{yy}- \beta_1S_{xy}$
#
# $SQE = 77,2708 -(-0,21572)(-341,9592)$
#
# $SQE = 3 ,5048$ 🐎

# %% [markdown]
# **PERGUNTA 5**
#
# Um conjunto de dados fornece os seguintes valores: $S_{XX} = 1585,2307$ ,  $S_{YY} = 77,2708$ e $S_{YY} = -341,9592$ e uma reta de regressão $Y = 9,10088 - 0,21572x_{i}$.

# %% [markdown]
# 🔪 $r^2=0,9546$ ☕
#
# $r^2=0,5645$
#
# $r^2=3189,4383$
#
# $r^2=0,3186$
#
# $r^2=77,2708$

# %% [markdown]
# 👣**Comentário da resposta:**🤘
#
# Os dados importantes para calcular o coeficiente de determinação $r^2$ são:
# $S_{yy} = 77,2708$ e $S_{xy} = -341,9592$  e $\beta_1$, sendo que a equação da reta é $Y = 9,10088 - 0,21572x_{i}$,e o valor de
# $\beta_1 = -0,21572$
# Com esses dados devem ser calculados SQE e SQT, já que deles depende o coeficiente de determinação $r^2 = 1- \frac{SQE}{SQT}$
#
# $ SQE = S_{yy} -\hat{β}_1S_{xy}$
#
# $ SQE = 77,2708 -(-0,21572)(-341,9592)$
#
# $ SQE = 3,5048$
#
# Da definição, tem-se que $SQT = S_{yy}$ portanto, $SQT = 77,2708$
#
# Finalmente, $r^2 = 1- \frac{3,5048}{77,2708}$
#
# $r^2 =0,9546$

# %% [markdown]
# **PERGUNTA 6**
#
# Observe a figura que representa um conjunto de dados bivariados, isto é, dados que apresentam informações semelhantes. Os dados, compostos por 20 amostras, estão bem correlacionados porque representam duas metodologias diferentes para obter a concentração de hidrogênio, esperando-se, portanto, que forneçam resultados semelhantes.
# Com esses dados foi realizado o procedimento de regressão obtendo as seguintes informações: reta de regressão $Y = -0,9625 + 1,001x$ , uma variância estimada de $0,3022$ e $S_{xx} = 40925,75$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Calcule o intervalo de confiança de $\beta_{1}$ a 95%

# %% [markdown]
# ⭕ $(0,9957 , 1,007)$  🦊

# %% [markdown]
# $(-09682,-0,9625)$

# %% [markdown]
# $(1,001 , 1,007)$

# %% [markdown]
# $(-0,9625 , - 0,9568)$

# %% [markdown]
# $(0,9957 , 1,001)$

# %% [markdown]
# 👓 **Comentário da resposta:** 🛵
#
#
# Como a reta é  $Y = -0,9625 + 1,001x$, então $\beta_1=1,001$ e  $s^2 = -0,3022$.
# Para calcular o erro padrão de $\beta_1$, use a seguinte equação:
#
# $S_{\hat{\beta}_1} = \sqrt{\frac{s}{S_{xx}}}$
#
# $S_{xx}$ é dado, mas $s$ deve ser calculado, pois só há como dado  $s^2$
#
# $s = \sqrt{s^2} = \sqrt{0,3022}= 0,5497$
#
# $SQE = S_{yy}- \beta_1S_{xy}$
#
# Assim:
#
# $S_{\hat{\beta}_1} = \frac{0,5497}{\sqrt{40925,75}}= 0,002717$
#
# Para calcular o intervalo de confiança (IC), deve ser usada a tabela t-student.
#
# $t_{\frac{α}{2},n-2}$ isto é $t_{0,025,18}$  já que n=20.
#
# Da tabela, $t_{0,025,18} = 2,101$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $\hat{β}_1 = β_1 ± t_{\frac{α}{2},n-2}S_{\hat{β}_1}$
#
# $\hat{β}_1 = 1,001 ± (2,101)(0,002717)$
#
# $0,9957 < \hat{β}_1 <1,007$ , assim, o IC é $(0,9957 ,1,007)$
