# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Modelagem e Inferência Estatística** 💻
# ###**Link**:https://ava.univesp.br/ultra/courses/_5842_1/cl/outline
# ##**Profa. Drª. Victoria Alejandra Salazar Herrera**💪
# ##**Aluno: Aelso Rocha Brito**👷
# ##**notebook**ComAnotaçõesDasVideoaulas✍
# ## **Semestre:** 01.2022
# ---

# %% [markdown]
# ##Semana 3 - Atividade Avaliativa

# %% [markdown]
# **PERGUNTA 1** 🔻
#
# Um conjunto de dados em que:
#
# x=Largura da fissura da pálpebra (isto é, a largura horizontal da abertura do olho, em cm).
#
# y=Área da Superfície Ocular (ASO) em $cm ^2$
#
# Foram verificados e apresentam uma relação linear.
#
# Verifique o comportamento desses dados utilizando o Google Colab https://colab.research.google.com/. Crie um novo documento e execute o seguinte código para definir os dados:

# %%
#Dados x
x=[0.40, 0.42, 0.48, 0.51, 0.57, 0.60, 0.70, 0.75, 0.75, 0.78, 0.84, 
    0.95, 0.99, 1.03, 1.12, 1.15, 1.20, 1.25, 1.25, 1.28, 1.30, 1.34, 1.37, 
    1.40, 1.43, 1.46, 1.49, 1.55, 1.58, 1.60]
#Dados y
y=.02, 1.21, 0.88, 0.98, 1.52, 1.83, 1.50, 1.80, 1.74, 1.63, 2.00, 
    2.80, 2.48, 2.47, 3.05, 3.18, 3.76, 3.68, 3.82, 3.21, 4.27, 3.12, 3.99,
    3.75, 4.10, 4.18, 3.77, 4.34, 4.21, 4.92]

# %% [markdown]
# Depois de definir os dados, execute o seguinte código para realizar a regressão linear via software.

# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
x=sm.add_constant(x)
modelo=sm.OLS(y, x).fit() #
print(modelo.summary())

# %% [markdown]
# Se o valor de  $t_{crit}=2,0484$  para um nível de confiança é 95%, analise o resultado apresentado e responda: qual é o valor do intervalo de confiança de b e t a subscript 1 (Realize também o cálculo manual para conferir o resultado do software).

# %% [markdown]
# 🥈  2,772<\beta_1}$<3,383 🐭✔

# %% [markdown]
# -2,367<${\beta_1}$<0,025

# %% [markdown]
# 0,151<${\beta_1}$<0,168

# %% [markdown]
# -0,3977<${\beta_1}$<3.0800

# %% [markdown]
# -0,742<${\beta_1}$<-0,054

# %% [markdown]
# **Comentário da resposta:**
#
# O resultado apresentado pelo software computacional pode ser observado na figura, abaixo do indicador [0,025 e 0,075] correspondendo a x1, isto é, $2,772$ e $3,383$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Se você realizar o cálculo manual para conferir os resultados do software, com ajuda do valor fornecido nos dados $t_{crit}=2,0484$
# e do resultado da figura acima  o $S_{\hat{\beta}_1}=0,151$ e $\beta_1=3,08$
#
# IC de $\beta_1=\hat{\beta_1}±t_{\frac{α}{2},n-2}S_{\hat{\beta}_1}$:
#
# $\beta_1=3,08±2,0484)(0,151)$
#
# $2,771<\beta_1<3,389$
#
# Existe uma diferença na terceira casa decimal, devido ao arredondamento para os cálculos manuais, pois o software usa mais casas decimais.

# %% [markdown]
# **PERGUNTA 2** 🐕
#
# Um conjunto de dados em que:
#
# x=Largura da fissura da pálpebra (isto é, a largura horizontal da abertura do olho, em cm).
#
# y=Área da Superfície Ocular (ASO) em $cm ^2$ .
#
# Foram verificados e apresentam uma relação linear.
#
# Verifique o comportamento desses dados utilizando o Google Colab https://colab.research.google.com/}. Crie um documento novo e execute o seguinte código para definir os dados:

# %%
#Dados x
x=[0.40, 0.42, 0.48, 0.51, 0.57, 0.60, 0.70, 0.75, 0.75, 0.78, 0.84, 
    0.95, 0.99, 1.03, 1.12, 1.15, 1.20, 1.25, 1.25, 1.28, 1.30, 1.34, 1.37, 
    1.40, 1.43, 1.46, 1.49, 1.55, 1.58, 1.60]
#Dados y
y=[1.02, 1.21, 0.88, 0.98, 1.52, 1.83, 1.50, 1.80, 1.74, 1.63, 2.00, 
    2.80, 2.48, 2.47, 3.05, 3.18, 3.76, 3.68, 3.82, 3.21, 4.27, 3.12, 3.99,
    3.75, 4.10, 4.18, 3.77, 4.34, 4.21, 4.92]

# %% [markdown]
# Depois de definir os dados, execute o seguinte código para realizar a regressão linear via software.

# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
x=sm.add_constant(x)
modelo=sm.OLS(y, x).fit() #
print(modelo.summary())

# %% [markdown]
# Calcule o  $t_{crit}$ para um nível de confiança de 95%.
#
# Finalmente, analise o resultado apresentado e responda: se aplicado o teste de funcionalidade do modelo, deve-se aceitar ou rejeitar a hipótese nula? (Dica: foque no parâmetro relevante para o teste de funcionalidade).

# %% [markdown]
# $H_0: \beta_1$=0 deve ser aceita, porque P(>|t|)=0,00

# %% [markdown]
# $H_0: \beta_0$=0 deve ser rejeitada, porque a estatística de teste é maior do que $t_{crit}$

# %% [markdown]
# $H_0: \beta_1$=0 deve ser aceita porque, a estatística de teste é maior do que  $t_{crit}$

# %% [markdown]
# ⏰ $H_0: \beta_1$=0 deve ser rejeitada, porque a estatística de teste é maior do que $t_{crit}$ ✔ 🚪

# %% [markdown]
# $H_0: \beta_0$=0 deve ser rejeitada, porque P(>|t|)=0,025

# %% [markdown]
# **Comentário da resposta:** 👈
#
# O resultado apresentado pelo software computacional pode ser observado na figura:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Atente-se aos resultados correspondentes a $\beta_ 1$, pois esse parâmetro indica a relação linear entre $x$ e $y$, $\beta_ 0$ indica apenas o valor do intercepto, portanto não é relevante para o teste de funcionalidade. É importante entender que não ser relevante não quer dizer que deva ser desconsiderado, ele não pode ser eliminado da reta, mas se ele valer zero, não indica que se anula a relação linear, só indica que quando $x=0$, $y=0$. Com isso em mente, as opções que tratam sobre inferências realizadas com $\beta_ 0$, apesar de ser verdadeiras, não são consideradas como opção correta visto que ela não define a utilidade do modelo.
#
# Nos resultados da imagem, observa-se que a estatística de teste (t) para $\beta_1=20,453$. Calculando o $ t_{critic}$ a 28 gl na tabela t-student, obtém-se $ t_{critic}=2,048$. Como  $20,453 > 2,048$, isto é, a estatística de teste (t) é maior do que o $ t_{critic}$, $H_0: \beta_ 1=0$ deve ser rejeitada.

# %% [markdown]
# **PERGUNTA 3** 🚒
#
# Considere o seguinte conjunto de dados, em que x=pH e y=arsênio removido (%) por um determinado processo.

# %%
x=[7.01, 7.11, 7.12, 7.24, 7.94, 7.94, 8.04, 8.05, 8.07, 8.90, 8.94, 8.95, 8.97, 8.98, 9.85, 9.86, 9.86, 9.87]
y=[60, 67 , 66, 52, 50, 45, 52, 48, 40, 23, 20, 40, 31, 26, 9, 22, 13, 7]

# %% [markdown]
# Estime os parâmetros da reta de regressão usando o software computacional e considerando que $S_{\hat{Y}}=1,61 $, calcule o intervalo de confiança da porcentagem de arsênico removido quando o pH vale 8,0. Utilize um nível de confiança de 99 %.

# %% [markdown]
# 🐧 41,291<${\hat{Y}_1}$<50,696 ✔ 🎸

# %% [markdown]
# 43,183<${\hat{Y}_1}$<48,805

# %% [markdown]
# 40,759<${\hat{Y}_1}$<51,230

# %% [markdown]
# 42,581<{\hat{Y}_1}$<49,407

# %% [markdown]
# 42,023<${\hat{Y}_1}$<49,975

# %% [markdown]
# **Comentário da resposta:** 🛸
# Neste caso, o IC solicitado considerará um valor de $x=8,0$ o IC de $\mu_{Y,8}$, pode-se calcular com $\hat{Y}_1± t_{\frac{\\alpha}{2}}{,n-2} S_\hat{Y}$.
#
# Como $n=18$, então $gl=16$, isto é, $n-2$, e como o nível de confiança é de $99\%$ $α=0,01$, é necessário obter $t_{0,005,16}$ da tabela t-student, o qual é $t_{0,005,16}=2.92078$
#
# Os dados do problema fornecem uma reta $Y=190,26829-18,03424x$, assim, para $x=8$
#
# $\hat{Y}=45,99433$, $S_{\hat{Y}}=1,61$
#
# então o IC de $Y_{08}$ será:
#
# $45,99433±(2.92078)(1,61)$
#
# $41,291<\hat{Y}<50,696$, logo, o intervalo é $(41,291,50,696)$.

# %% [markdown]
# **PERGUNTA 4** ☠
#
# Calcule a reta de regressão linear dos dados a seguir, em que x=pH e y=arsênio removido (%) por um determinado processo. Verifique se o coeficiente de determinação e as estatísticas de teste indicam que o modelo descreve a relação linear entre essas variáveis, depois calcule a porcentagem de arsênio removido que pode se esperar para um pH=8,0, adotando para o cálculo o menor $\beta_1$  fornecido pelo intervalo de confiança de $\beta_1$.
#
# Use o Google Colab https://colab.research.google.com/. Crie um novo documento e execute os códigos necessários para esse objetivo.
# Seguem os dados das variáveis.

# %%
 x=[7.01, 7.11, 7.12, 7.24, 7.94, 7.94, 8.04, 8.05, 8.07, 8.90, 8.94, 8.95, 8.97, 8.98, 9.85, 9.86, 9.86, 9.87]
 y=[60, 67 , 66, 52, 50, 45, 52, 48, 40, 23, 20, 40, 31, 26, 9, 22, 13, 7]

# %% [markdown]
# 🦚 $\mu_y,_8$=20,9972✊ ✔

# %% [markdown]
# $\mu_y,_8$=45,9943

# %% [markdown]
# $\mu_y,_8$=79.9915

# %% [markdown]
# $\mu_y,_8$=24,3790

# %% [markdown]
# $\mu_y,_8$=20,000

# %% [markdown]
# **Comentário da resposta:**
#
# Neste exercício está sendo solicitado o calculo do intervalo de confiança de $β_1$ e o uso do menor valor desse intervalo para calcular $\mu_y,_8$. Para poder estimar este dado é necessário, primeiro, executar um código que forneça os parâmetros da reta de regressão e o intervalo de confiança de $\beta_1$.
#
# No Python pode-se realizar como segue, mas não está restrito a essa opção, pois você mesmo pode criar seu código, usar bibliotecas semelhantes, ou outros softwares, como R ou Excel:

# %%
 #obtenção da reta de regressão e outros parâmetros importantes
# antes de executar o código não esqueça de definir as variáveis x e y
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
x=sm.add_constant(x)
modelo=sm.OLS(y, x).fit() #
print(modelo.summary())

# %% [markdown]
# Observe os resultados na imagem:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para pegar os valores dos parâmetros opcionalmente, você pode usar o seguinte código ou pegar manualmente do resultado apresentado no código anterior.

# %%
# parâmetros da reta
b=modelo.params
b0=b[0]#intercepto
b1=b[1]#inclinação
b0 #o valor de b0 se mantem na reta

# %% [markdown]
# Para verificar os valores das estatísticas de teste para os parâmetros e o valor do coeficiente de determinação, você pode opcionalmente executar o seguinte código ou observar no resultado do sm.OLS.

# %%
#estatística de teste para b0 e b1
tb=modelo.tvalues 
tb0=tb[0] # estatística de teste de hipótese nula para b0
tb1=tb[1] # estatística de teste de hipótese nula para b1
#r^2 coeficiente de determinação
r2=modelo.rsquared  
tb,r2

# %% [markdown]
# Os valores das estatísticas de teste são altos, portanto, adotam valores maiores ao $t_{crit}$ para níveis de confiança altos (maiores do que 99%) e $r ^2=0,903$.
#
# Com essas considerações pode-se considerar o modelo como aceito, pois vistos os dados das estatísticas de teste as hipóteses nulas serão rejeitadas.
#
# Com os valores obtidos a reta será $Y=190,2683-18,0342x$, mas veja que o intervalo de confiança de $\beta_1$ é $(-21,159,-14,910)$, isto é, os valores mínimo e máximo. Como foi solicitado calcular o valor de $μ_{y,8}$ para o mínimo valor da inclinação, deve-se adotar $\beta_1=-21,159$.

# %%
 #obter os valores do intervalo de confiança de b1
a=modelo.conf_int()
a1=a[1] #obter IC de b1
uy1=b0+a1[0]*8 #a1[0] é o valor mínimo
uy1

# %% [markdown]
# Sendo o resultado $μ_{y,8}=20,9972$.Atente-se que este dado pode ficar fora do IP porque foi considerada uma alteração na reta ajustada, apenas com o objetivo de você verificar os resultados. Se ficou curioso(a) recomendo calcular o IP.

# %% [markdown]
# **PERGUNTA 5** 🛁
#
# A regressão linear se realiza para verificar a relação existente entre duas ou mais variáveis. Considerando apenas duas variáveis, o processo de regressão linear fornece como resultado dois parâmetros: $\beta_0$ e $\beta_1$.Em um desses parâmetros, aplica-se o teste de hipótese para verificar a utilidade do modelo porque, se este teste valida $H_0$ , significa que x não fornece informações a respeito de y.
#
# Assinale a alternativa que representa corretamente a hipótese nula e verificação da utilidade do modelo.

# %% [markdown]
# 🪐 $H_0: \beta_1=0$ versus $H_a: \beta_0 ≠ 0$ 🐒 ✔

# %% [markdown]
# $H_0: \beta_1=\beta_10$ versus $H_a: \beta_1> \beta_10$

# %% [markdown]
# $H_0 : \beta_1=0$ versus $H_a: \beta_1>≠0$

# %% [markdown]
# $H_0: \beta_1=\beta_10$ versus $H_a: \beta_1<\beta_10$

# %% [markdown]
# $H_0: \beta_1=\beta_10$ versus $H_a: \beta_1≠ \beta_10$

# %% [markdown]
# **Comentário da resposta:**
#
# O teste de utilidade do modelo é importante, sem ele não é adequado usar o modelo obtido para fazer previsões, pois pode levar a previsões incorretas.
#
# Observe que a opção $H_0:\beta_1=0$ versus $H_a:\beta_0 ≠ 0$ está incorreta, porque um teste de hipótese contrapõe um valor do parâmetro contra outro do mesmo parâmetro, e na alternativa há dois parâmetros diferentes na hipótese.
#
# As opções:
#
# $H_0:\beta_1=\beta_{10}$  $\textit{versus}$ $ H_a:\beta_1 ≠ \beta_10$
# $H_0:\beta_1=\beta_{10}$  $\textit{versus}$ $H_a:\beta_1 > \beta_10$
# $H_0:\beta_1=\beta_{10}$  $\textit{versus}$ $H_a:\beta_1<\beta_10$
#
#
#
# São propostas corretas de teste de hipótese, porém são utilizadas para verificar se o parâmetro em questão poderia adotar um valor diferente, menor ou maior do que algum valor $\beta_{10}$.
#
# Veja que o teste de utilidade do modelo testa especificamente se $H_0:\beta_1=0$ versus $H_a:\beta_1≠0$, já que, se a hipótese nula for verdadeira, não é possível utilizar o modelo, pois $X$ não tem nenhum impacto em $Y$, sendo impossível, dessa forma, fazer inferências com os dados dessas duas variáveis.

# %% [markdown]
# **PERGUNTA 6** ⚾
#
# Considerando um conjunto de duas variáveis, o processo de regressão linear forneceu como resultado uma reta dois parâmetros: Y=190,2+1,245x.Foi realizado um teste de hipótese para utilidade do modelo para essa reta. Os resultados do $t_{crit}$  e da estatística de teste $t$ foram 2,947 e -1,543, respectivamente.
#
# Após analisar o resultado do teste, leia as alternativas e escolha a que representa corretamente o resultado do teste junto à reta.

# %% [markdown]
# $H_0: \beta_1=0 $ se rejeita, portanto  Y=190,2 +1,245

# %% [markdown]
# $H_0: \beta_1=0 $ se rejeita, portanto Y=1,245x

# %% [markdown]
# 🧛 $H_0: \beta_1=0 $ é verdadeira, portanto Y=190,2 🍉✔

# %% [markdown]
# $H_0: \beta_1=0 $ é verdadeira, portanto Y=1,245x

# %% [markdown]
# Os dados fornecidos não indicam se o teste se realizou em $\beta_1$ ou em $\beta_0$

# %% [markdown]
# **Comentário da resposta:**
#
# De acordo com as informações $t_{crit}=2,947$ e $t=- 1.543$, para rejeitar a hipótese, deve-se cumprir que $|t| ≥ t_{crit}$ , substituindo os valores $t=-1.543≥2,947$ é falso, ou seja, a hipótese nula $H_0:β_1=0$ é verdadeira.
#
# $Y=190,2+0x$ ou, simplesmente, $Y=190,2$. O que significa que os dados de $x$ não têm nenhum efeito na variável $Y$, invalidando o modelo.

# %% [markdown]
# **PERGUNTA 7** 👻
#
# Foi analisado um conjunto de dezoito dados x e y, que forneceram os seguintes resultados:
#
# $Σ$xi=152,70
#
# $Σ$yi=671,00
#
# $Σ$xiyi=5380,84
#
# $Σxi ^2$=1312.6764
#
# $Σyi^ 2$=31231,00
#
# $\bar{x}=8.4833$
#
# $\bar{y}=37.2778$
#
# Calcule os intervalos de confiança do valor esperado de três amostras com um nível de confiança de, pelo menos, 97%. As amostras adotam os seguintes valores x1=7, x2=8 e x3=9.
#
# Uma vez realizados todos os cálculos, verifique os seguintes itens que contêm alguns resultados:
#
# I. $\beta_0=190,268$ e $\beta_1=18,034$
#
# II. $SQE=6217,61$
#
# III.$\mu_y,_7$=64,030
#
# IV. Para x=9, $S{\hat{y}}$=1,7104
#
# V.Para x=8, o intervalo é 41,293<$\mu_y,8=1,7104$<50,699
#
# Finalmente, após comparar os resultados com os seus, escolha a alternativa correta

# %% [markdown]
#
# Apenas III, IV e V são verdadeiras.

# %% [markdown]
# Apenas IV é verdadeira.

# %% [markdown]
# Apenas I, III e V são verdadeiras.

# %% [markdown]
# 🚴 **Apenas III e V são verdadeiras.**✔ 🍂

# %% [markdown]
# Apenas I e II são verdadeiras.

# %% [markdown]
# **Comentário da resposta:** 🧴
#
# Com os dados do problema é possível encontrar as relações de $S_{xx}$ ,$S_{yy}$ e $S_{xy}$ , de acordo com o número de dados da amostra $n=18$.
#
# $S_{xx}=∑(x_i^2) - \frac{(∑(x_i))^2}{n}=1312,6764-\frac{(152,70)^2}{18}$
#
# $S_{xx}=17,2714$
#
# $S_{yy}=∑(y_i^2)-\frac{(∑(y_i))^2}{n}=31231-\frac{(671)^2}{18}$
#
# $S_{yy}=6217,61$
#
# $S_{xy}=∑(x_iy_i) - \frac{∑(x_i)∑(y_i)}{n}=5380,84-\frac{(152,70)(671)}{18}$
#
# $S_{xy}=-311,4767$
#
# Com estes dados é possível calcular os parâmetros do modelo de regressão linear:
#
# $\beta_{1}=\frac{S_{xy}}{S_{xx}}=\frac{-311,4767}{17.2714}$
#
# $\beta_1=- 18,034$  \textbf{com signo negativo, invalidando a afirmativa I}
#
# $\beta_0=\bar{y} -\beta_1=\bar{x}(- 18,034)(8,4833)$
#
# $\beta_0=190,268$

# %% [markdown]
# Portanto, a reta de regressão para esses dados é $Y=190,268 - 18,034x$.
# Com essa reta, podem ser calculados os valores esperados de $Y$ para os três valores de $x$.
#
# $\mu_{y,7}=190,268 - 18,034 (7)=64,030$ **Validando a afirmativa III**
#
# $\mu_{y,8}=190,268 - 18,034 (8)=45,996$
#
# $\mu_{y,9}=190,268 - 18,034 (9)=27,962$
#
# Agora o IC pode ser calculado com $\hat{Y}± t_{\frac{\alpha}{2}}{,n-2} S_\hat{Y}$.
#
# Como são três amostras, considere que $100(1-k\alpha)\% ≈ 97$, em que a quantidade de observações simultâneas $k=3$, então encontre $\alpha$
#
# $(1 - k \alpha)=0,97$
#
# $1 - 3 \alpha=0,97$
#
# $\alpha=\frac{0.03}{3}=0,01$
#
# Assim, o $t_{\frac{\alpha}{2},n-2}=t_{0,005,16=2.92078}$

# %% [markdown]
# e $s_\hat{Y}=s\sqrt{(\frac{1}{n}} + \frac{(x^* - \bar{x})^2}{S_{xx}})$
#
# $S_{xx}$  é dado, mas s deve ser calculado, para isso é necessário calcular primeiro $SQE$ e com esse valor calcular $s^2$.
#
# $SQE=S_{yy}-\beta _1S_{xy}=6217,61-(18,034)(-311,4767)=600,4392$ **invalidando a afirmativa II**
#
# $s^2=\frac{SQE}{n - 2}=\frac{600,4392}{18 - 2}$
#
# $s^2=\sqrt{s^2}=\sqrt{\frac{600,4392}{18-2}}=6,126$
#
# Uma vez tendo todos os valores, calcule:
#
# $s_\hat{Y}=s\sqrt{(\frac{1}{n}} + \frac{(x^* - \bar{x})^2}{S_{xx}})$
#
# Para $x=7$
# $s_\hat{Y}=6,126\sqrt{(\frac{1}{18}} + \frac{(-7 - 8,4833)^2}{17,2714})$ Assim $s_\hat{Y}=2,6202$
#
# Para $x=8$
# $s_\hat{Y}=6,126\sqrt{(\frac{1}{18}} + \frac{(-8 - 8,4833)^2}{17,2714})$. Assim $s_\hat{Y}=1,6101$
#
# Para $x=9$
# $s_\hat{Y}=6,126\sqrt{(\frac{1}{18}} + \frac{(-9 - 8,4833)^2}{17,2714})$ Assim $s_\hat{Y}=1,6325$ **invalidando a afirmativa IV**

# %% [markdown]
# Observe que quanto mais próximo o valor $x^*$ está da média, menor o valor de $s_\hat{Y}=$.
#
# Finalmente, os intervalos são calculados com $\hat{Y}± t_{0,005,16}S_\hat{Y}$.
#
# Para $x=7$, o intervalo é $56,377<\mu_{y,7}<71,683$ ou $(56,377,71,683)$.
#
# Para $x=8$, o intervalo é $41,293<\mu_{y,8}<50,699$ ou $(41,293,50,699)$, **validando a afirmativa V**
#
# Para $x=9$, o intervalo é $23,194<\mu_{y,9}<32,730$ ou$(23,194,32,730)$.
#
# **Portanto, apenas III e V são verdadeiras.** 😶

# %% [markdown]
# **PERGUNTA 8** 🤡
#
# Foi analisado um conjunto de dezoito dados x e y, que forneceram os seguintes resultados:
#
# $Σ$xi=152,70
#
# $Σ$yi=671,00
#
# $Σ$xiyi=5380,84
#
# $Σxi ^2$=1312.6764
#
# $Σyi^ 2$=31231,00
#
# $\bar{x}=8.4833$
#
# $\bar{y}=37.2778$
#
# Calcule o intervalo de previsão de 95% para x=9.

# %% [markdown]
# 5,50472<${\hat{Y}_1}$<32,38528

# %% [markdown]
# 23,19386<${\hat{Y}_1}$<32,73014

# %% [markdown]
# 🐠 $14,42172<{\hat{Y}_1}<41,40288$ ✔ 🥗

# %% [markdown]
# 32,55571<${\hat{Y}_1}$<59,43628

# %% [markdown]
# 16,32512<${\hat{Y}_1}$<43,20568

# %% [markdown]
# **Comentário da resposta:** 🧯
#
# Com os dados do problema é possível encontrar as relações de $S_{xx}$ ,$S_{yy}$ e $S_{xy}$ , de acordo com o número de dados da amostra $n=18$.
#
# $S_{xx}=∑(x_i^2) - \frac{(∑(x_i))^2}{n}=1312,6764-\frac{(152,70)^2}{18}$
#
# $S_{xx}=17,2714$
#
# $S_{yy}=∑(y_i^2)-\frac{(∑(y_i))^2}{n}=31231-\frac{(671)^2}{18}$
#
# $S_{yy}=6217,61$
#
# $S_{xy}=∑(x_iy_i) - \frac{∑(x_i)∑(y_i)}{n}=5380,84-\frac{(152,70)(671)}{18}$
#
# $S_{xy}=-311,4767$
#
# Com estes dados é possível calcular os parâmetros do modelo de regressão linear:
#
# $\beta_{1}=\frac{S_{xy}}{S_{xx}}=\frac{-311,4767}{17.2714}$
#
# $\beta_1=- 18,034$  \textbf{com signo negativo, invalidando a afirmativa I}
#
# $\beta_0=\bar{y} -\beta_1=\bar{x}(- 18,034)(8,4833)$
#
# $\beta_0=190,268$

# %% [markdown]
# Portanto, a reta de regressão para esses dados é $Y=190,268 - 18,034x$.
#
# Com essa reta pode ser calculado o valor esperado de Y para x=9.
#
# $Y_{9}=190,268 - 18,034 (9)=27,962$
#
# Agora o IP de $Y_{9}$ pode ser calculado com $\hat{Y}± t_{\frac{\alpha}{2}}{,n-2}\sqrt{s^2 + s_{\hat{y}}^2)}$.

# %% [markdown]
# Portanto, é necessário calcular o valor da variância esperada $s^2$, que depende de $SQE$.
#
# $SQE=S_{yy}-\beta _1S_{xy}=6217,61-(18,034)(-311,4767)=600,4392$
#
# $s^2=\frac{SQE}{n - 2}$
#
# $s^2=\frac{600,4392}{18 - 2}$
#
# $s^2=37,52745$
#
# $s^2=\sqrt{s^2}=6,126$
#
# Agora é necessário procurar o $t_{\frac{\alpha}{2}{,n-2}}$, como o´nível de confiança é 95\%, então $\alpha=0,05$, e como são 18 amostras $t_{0,005,16}$, procurando na tabela t-student, $t_{0,005,16}=2,120$.
#
# O último dado necessário é s subscript Y with hat on top end subscript que deve ser calculado como segue:
#
#
#
# $s_\hat{Y}=s\sqrt{(\frac{1}{n}} + \frac{(x^* - \bar{x})^2}{S_{xx}})$
#
#
# Para $x=9$
# $s_\hat{Y}=6,126\sqrt{(\frac{1}{18}} + \frac{(-9 - 8,4833)^2}{17,2714})$ Assim $s_\hat{Y}=1,6325$

# %% [markdown]
# O IP de $Y_9$ pode ser calculado com  $\hat{Y}± t_{0,025,16} \sqrt{s^2 + s_{\hat{Y}}^2)}$
#
# Finalmente, para $x=9$ o IP será:
#
# $27,962±(2,120)\sqrt{37,52745+1,6325^2}$
#
# $14,42172<{\hat{Y}_1}<41,40288$ , logo, o intervalo é $(14,52172,41,40288)$.
