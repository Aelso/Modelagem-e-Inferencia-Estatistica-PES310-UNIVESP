# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Modelagem e Inferência Estatística** 💻
# ###**Link**:https://ava.univesp.br/ultra/courses/_5842_1/cl/outline
# ##**Profa. Drª. Victoria Alejandra Salazar Herrera**💪
# ##**Aluno: Aelso Rocha Brito**👷
# ##**notebook**ComAnotaçõesDasVideoaulas✍
# ## **Semestre:** 01.2022
# ---

# %% [markdown]
# **PERGUNTA 1** 🦆
#
# Na tabela a seguir, apresentamos a menor $SQE$ para cada número $k$ de preditores ($k = 1, 2, 3, 4$) para um problema de regressão de variáveis múltiplas.
#
# |Número k de preditores |variáveis |$SQE$  |
# |-----------------------|----------|-------|
# |1	                    |x4	       |880,85 |
# |2                    	|x1,x2	   |58,01  |
# |3	                    |x1,x2,x3	 |49,20  |
# |4	                    |x1,x2,x3,x4|	47,86|
#
# Sabendo que $SQT= 2969,6$ e  $n=13$, complemente essa tabela calculando o valores de $R^2$, $R_a^2$ e $C_k$ para os casos apresentados (em cada linha) e indique quantos preditores (k) precisa o modelo para representar melhor o conjunto de dados.
# (Dica: para calcular $C_k$, precisará calcular de $s^2$).

# %% [markdown]
# $k=4$ porque quanto mais preditores mais confiável o modelo.

# %% [markdown]
# 🦒 $k=2$ porque apresenta um $C_k$ pequeno com valores grandes para $R^2$ e $R_a^2$. 🤟

# %% [markdown]
# k=2 porque apresenta um $C_k$ pequeno com valores grandes para $R^2$ e $R_a^2$.

# %% [markdown]
#
# $k=1$ porque apresenta o menor $C_k$.

# %% [markdown]
# $k=4$ porque apresenta $R^2$ e $R_a^2$ grandes e o maior $C_k$.

# %% [markdown]
# $k=3$ porque apresenta o maior $R_a^2$ e $R^2$ também grande.

# %% [markdown]
# **Comentário da resposta:**
#
# O critério $C_k$ pode ser usado para a escolha do modelo mais adequado em complemento com o valor $R^2$ e  $R_a^2$. Este critério responde a o menor valor de $C_k$ para valores grandes $R^2$ e $R_a^2$.
#
# Também pode se usar este critério para a escolha de amostras influentes.
#
# Para calcular os valores de $R^2$, $R_a^2$ e $C_k$, são necessárias as seguintes equações:
#
# $R^2 =1-\frac{SQE}{SQT}$($SQE$ obtido para cada $k$ e $SQT=2969,6$ para todos)
#
# $R_a^2 = \frac{n-1}{n - ( k + 1 )} \frac{SQE}{SQT} $ ($SQE$ e $k$ obtidos para cada valor de $k$, $SQT2=969,6$ e $n=13$ para todos)
#
# $C_k = \frac{SQE}{s^2}+2(k + 1)-n$, em que $s^2=\frac{SQE}{n - ( k + 1 )}$ dita variância, deve ser calculada também para cada linha.
#
# Substituindo os valores nessas equações para os quatro casos, obtém-se a seguinte tabela:

# %% [markdown]
# |Número k de preditores |variáveis  |$SQE$  |$R^2$|$R_a^2$|$s^2$|$C_k$|
# |-----------------------|-----------|-------|-----|-------|-----|-----|
# |1	                |x4	    |880,85 |0,703|NA|80,0773|2|
# |2                    	|x1,x2	    |58,01  |0,980|0,9766|5,8040|3|
# |3	                |x1,x2,x3   |49,20  |0,983|0,9779|5,4667|4|
# |4	                |x1,x2,x3,x4|47,86  |0,984|0,9758|5,9825|5|

# %% [markdown]
# Analisando a tabela, pode-se concluir que um modelo com $k=2$ preditores, especificamente $x1$ e $x2$, apresenta um $C_k$ pequeno com valores grandes para $R^2$ e $R_a^2$, observe que o menor valor de $C_k$ adota um valor notoriamente menor de $R^2$, portanto a escolha aponta a $k=2$.

# %% [markdown]
# **PERGUNTA 2** 😶
#
# Na imagem a seguir apresenta-se um gráfico que contem no eixo x valores críticos versus os resíduos studentizados, ambos valores visam definir as amostras influentes.
#
# Interpretando o gráfico, é possível afirmar que:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ParaTodosVerem Apresenta-se um gráfico com circunferências em azul, algumas delas adotan tamanhos pequenos, outras tamanhos médios (elas estão mais alocadas para acima) e um é uma circunferência maior.

# %% [markdown]
# é um gráfico evidencia os valores maiores e menores dos dados.
#
# é um gráfico de distribuição t-student.
#
# é um gráfico de distribuição normal dos erros.
#
# é um gráfico de dispersão dos dados.
#
# 🦊 é um gráfico que evidencia amostras influentes. 🎃

# %% [markdown]
# **Comentário da resposta:**
#
# O gráfico que evidencia amostras influentes usando para este propósito o tamanho de cada circunferência, quanto maior mais influente é a amostra. No gráfico apresentam-se 3 circunferências maiores do que o resto, e a maior delas corresponde ao critério $C_k$.

# %% [markdown]
# **PERGUNTA 3** 🐙
#
# Um conjunto de dados foi ajustado mediante um modelo logístico de variáveis múltiplas:
#
# $\frac{p(x_1,x_2 ,...,x_k)}{1 -p(x_ 1,x_ 2 ,...,x_ k)}=e^{\beta_0 + \beta_1x_1 + \beta_2x_2}$
#
# Se $\beta_ 0=4,24$, $\beta_ 1=0,46$ e $\beta_ 2=1,18,$ calcular a razão das chances para a variável $x_2$ quando as outras se mantêm fixas.

# %% [markdown]
# A razão das chances é $1,58$.
#
# A razão das chances é $0,46$.
#
# A razão das chances é $4,24$.
#
# A razão das chances é $1,18$.
#
# ✋ A razão das chances é $3,25$. ⚡

# %% [markdown]
# **Comentário da resposta:**
#
# Para o modelo:
#
# $\frac{p(x_1,x_2 ,...,x_k)}{1 -p(x_ 1,x_ 2 ,...,x_ k)}=e^{\beta_0 + \beta_1x_1 + \beta_2x_2}$
#
# Onde $\beta_0=4,24$, $\beta_1=0,46$ e $\beta_2 =1,18$
#
# Se todas as variáveis menos $x_2$ se mantêm constantes, a razão das chances se calcula considerando o $e^{\beta_2}$, assim:
#
# $e^{\beta_2}=e^{1,18} =3,2543$, na resposta considerou-se apenas duas casas decimais.

# %% [markdown]
# **PERGUNTA 4** 🐆
#
# Um conjunto de amostras deverá ser ajustado com o seguinte modelo $y=\alpha e^{\beta_ 1 x_ 1 } e^{\beta_2x_2}\epsilon$ com erro multiplicativo.
#
# Para realizar corretamente o processo de regressão, é necessário realizar a transformação de variáveis para o modelo ser representado como linear.
#
# Qual das seguintes alternativas contém o modelo linearizado?

# %% [markdown]
# 🧊 $ln(y)=ln(\alpha) + \beta_1x_1 + \beta_2x_2 + ln(\epsilon)$ 👶
#
# $y=ln(\alpha) + \beta_ 1 x_ 1 + \beta_ 2 x_ 2 + ln(\epsilon) ou y=log(\alpha) + \beta_ 1 x_ 1 + \beta_ 2 x_ 2 + log(\epsilon)$
#
# $ln(y)=\alpha + \beta_ 1 ln(x_ 1) + \beta_ 2 ln(x_ 2) + \epsilon$
#
# $ln(y)=\alpha + \beta_ 1 x_ 1 + \beta_ 2 x_ 2 + \epsilon$
#
# $y=log(\alpha) + \beta_ 1 x_ 1 + \beta_ 2 x_ 2 + log(\epsilon)$

# %% [markdown]
# **Comentário da resposta:**
# Na equação $y=\alpha e^{\beta_ 1 x_ 1 } e^{\beta_2x_2}\epsilon$ recomenda-se trabalhar com logaritmo natural devido a se tratar de uma função exponencial, se o logaritmo em base $10$ for usado $log(e)=0,4343$ diferente de $ln(e)=1$. Na função potência, qualquer logaritmo pode ser usado indistintamente.
#
# Assim, pelas propriedades de logaritmos:

# %% [markdown]
# $ln(y)=ln(\alpha e^{\beta_1x_1} e^{\beta_2x_2 }\epsilon)$

# %% [markdown]
# $ln(y)=ln(\alpha)+ln(e^{\beta_1x_1})+ln(e^{\beta_2x_2})+ln(\epsilon)$

# %% [markdown]
# $ln(y)=ln(\alpha)+\beta_1x_1ln(e) +\beta_2x_2ln(e) +ln(\epsilon)$

# %% [markdown]
# como $ln(e)=1$ a equação linearizada será:
#
# $ln(y)=ln(\alpha)+\beta_1x_1+\beta_2x_2+ln(\epsilon)$

# %% [markdown]
# **PERGUNTA 5** 🦌
#
# Na imagem a seguir apresenta-se um mapa da correlação que existe entre as variáveis resposta ($lny$) e variáveis preditoras ($lnx1$, $lnx2$, $lnx3$) de um modelo de variáveis múltiplas.
#
# Leia as seguintes afirmativas sobre a interpretação do gráfico:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ParaTodosVerem Figura que representa um mapa de calor, sendo azul o menor valor (-1) e vermelho escuro o maior (1), percorre uma gama de cores de azul, azul claro, cinza, laranja claro, laranja e vermelho. A imagem está representada em forma de matriz 4x4. As linhas estão organizadas na seguinte ordem: lnx1,lnx2,lnx3 e lny, as colunas tem a mesma ordem. Na linha 1 apresentam-se os seguintes valores, 1, -0, -0, 0,83, na segunda linha os valores $-0. 1, 0, -0.05, $na terceira linha os calores $-0, 0, 1, 0,12$, na quarta linha os valores $0,83, -0.05, 0,12$ e $1$.
#
# Os valores da diagonal representam o coeficiente de determinação do modelo.
# Pode-se afirmar que existe correlação de $0,83$ entre $lnx1$ e $lny$.
# Pode-se afirmar que não existe correlação entre $lnx3$ e $lnx2$.
# As variáveis preditoras não apresentam correlação entre si, o que indica a possibilidade de não existir multicolinearidade.
# A variável preditora que está melhor correlacionada com a variável resposta é $lnx2$.
#
# Após analisar as afirmativas, é correto o que se afirma em:

# %% [markdown]
#
#
# Apenas II, III e V.
#
# Apenas II, III.
#
# 📡 **Apenas II, III e IV.** 🦌
#
# Apenas I, II, e IV.
#
# Apenas I, III e V.

# %% [markdown]
# **Comentário da resposta:**
#
# **Afirmativa I. Incorreta.** Neste gráfico, os valores da diagonal representam o coeficiente de CORRELAÇÃO entre uma variável e si mesma, portanto, é sempre 1.
#
# **Afirmativa II. Correta**. Pode-se afirmar que existe correlação de 0,83 entre lnx1 e lny. O que se observa em cor laranja escura.
#
# **Afirmativa III. Correta.** Pode-se afirmar que não existe correlação entre lnx3 e lnx2, na intersecção dessas variáveis observa-se o valor de 0,00.
#
# **Afirmativa IV. Correta.** As variáveis preditoras não apresentam correlação entre si, o que indica a possibilidade de não existir multicolinearidade. Sim, o valor entre lnx3 e lnx2 é 0,00, entre lnx3 e lnx1 é -0.00, entre lnx1 e lnx2 é -0.00. É possível que não exista multicolinearidade, mas é preciso verificar o VIF.
#
# **Afirmativa V. Incorreta.** A variável preditora que está melhor correlacionada com a variável resposta é lnx2. O R entre essas variáveis é -0,05, portanto a correlação é baixa. A melhor correlação observada é entre lnx1 e lny.

# %% [markdown]
# **PERGUNTA 6** 🐪
#
# Após o processo de ajuste do modelo, foi obtida uma equação com 3 variáveis preditoras, linear e sem interação. Treze amostras compõem o conjunto de dados, com eles foram calculados os coeficientes $h_{ij}$, e os resultados da diagonal ($h_{jj}$) são apresentados na seguinte tabela.
#
# |Número de amostra|	$h_{jj}$   |
# |-----------------|------------|
# |1 |0.358|
# |2 |0.200|
# |3 |0.214|
# |4 |0.167|
# |5 |0.658|
# |6 |0.131|
# |7 |0.934|
# |8 |0.339|
# |9 |0.358|
# |10|0.144|
# |11|0.237|
# |12|0.167|
# |13|0.237|
#
# Considerando o critério  fraction numerator $\frac{2(k + 1)}{n }$, qual ou quais amostras podem ser consideradas influentes?

# %% [markdown]
# Amostras 4, 6, 10 e 12.
#
# 🌍 Amostras 5 e 7. 🦎
#
# Amostra 7.
#
# Nenhuma amostra é influente.
#
# Todas as amostras, exceto 5 e 7.

# %% [markdown]
# **Comentário da resposta:**
#
# Para a escolha das amostras influentes, pode-se considerar dois critérios
# $h_{jj}>\frac{2(k+1)}{n}$ ou $h_{jj}>\frac{3(k+1)}{n}$.
#
# No enunciado foi solicitado o primeiro desses critérios, isto é:
#
# $h_{jj}>\frac{2(3+1)}{13}$ (como o modelo tem $3$ variáveis preditoras $k=3$)
#
# $h_{jj}>0,6154$
# existem duas amostras na tabela que têm o valor maior do que $0,6154$, isto é, as amostras 5 e 7.
#
#
# |Número de amostra|$h_{jj}$    |
# |-----------------|------------|
# |5                |       0.658|
# |7                |	  0.934|

# %% [markdown]
# **PERGUNTA 7** 🍓
#
# Na imagem a seguir apresentam-se alguns resultados da regressão de variáveis múltiplas de primeira ordem sem interação, considerando $k=3$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ParaTodosVerem Resultado do python, seguem os valores transcritos
#
# R-squared:                       0.858
# Adj. R-squared:                  0.811
# F-statistic:                     18.17
# Prob (F-statistic):           0.000369
#
# Após esses dados, tem uma tabela com 5 linhas e 7 colunas, na primeira coluna tem os nomes das variáveis e no resto das colunas, os seguintes títulos: coef, std err,t, P>|t|,$[0.025, e  0.975]$
# essa informação é para a primeira linha. Nas outras quatro linhas tem a seguinte informação:
#
# 2da linha: Intercept,$13.8973, 1.640, 8.475, 0.000 10.188,17.607$
#
# 3ra linha: cap_vol, $-0.0005, 0.001, -0.417, 0.686, -0.003, 0.002$
#
# 4ta linha: power, $-0.0061, 0.016, -0.378, 0.714, -0.043, 0.030$
#
# 2da linha: weight, $-0.0021, 0.001, -1.464, 0.177, -0.005, 0.001$
#
# As palavras Intercept, cap_vol, power, weight são nomes de variáveis, apenas, poderiam, por exemplo, ser $x1$, $x2$, $x3$ e $x4$.

# %% [markdown]
# É necessário realizar o teste de utilidade do modelo com um nível de significância de 95%, para este propósito foi calculado o valor $F_{crit}$, sendo ele igual a $4,066$ e o $t_{crit}=2,306$.
#
# Considerando esses valores críticos e os valores apresentados na imagem é possível afirmar que:

# %% [markdown]
#
# Como $f>F_{crit}$, rejeita-se a hipótese nula $H_0$, isto é, pelo menos um dos $\beta_ i ≠ 0$, mas não é possível saber quais parâmetros são.

# %% [markdown]
# Como $t>t_{crit}$, para $\beta_ 0$, rejeita-se a hipótese nula $H_0$, isto é, todo $\beta_ 0 ≠ 0$.

# %% [markdown]
# Como $f>F_{crit}$, rejeita-se a hipótese nula $H_0$, isto é, todo $\beta_ i ≠ 0$.

# %% [markdown]
# 🥫 **como $f>F_{crit}$, rejeita-se a hipótese nula $H_0$, isto é, pelo menos um dos $\beta_ i ≠ 0$. Os parâmetros diferentes de zero são $\beta_ 0$ e $\beta_ 1$.** 💎

# %% [markdown]
# Como $t>t{ crit}$, para $\beta_ 1$, rejeita-se a hipótese nula $H_0$, isto é, todo $\beta_ 1 ≠ 0$.

# %% [markdown]
# **Comentário da resposta:**
#
# Da imagem dos resultados $f=18,17$ e do enunciado $F_{crit}=4,066$, assim cumpre-se que $f > F_{crit}$. Essa relação indica que se rejeita a hipótese nula $H_0$, isto é, pelo menos um dos $\beta_i≠0$. Com esses dados não se pode saber quais parâmetros são diferentes de zero, porém o enunciando fornece também o $t_{ crit}=2,306$ e nos resultados da imagem apresentam-se as estatísticas de teste para cada parâmetro. Da imagem dos resultados pode se conferir que

# %% [markdown]
# Para $\beta_0$ $t=8,475$, isto é, |t| > $t_{ crit}$, portanto $\beta_0≠0$.
#
# Para $\beta_1$ $t=-2,417$, isto é, |t| > $t_{ crit}$, portanto $\beta_1≠0$.
#
# Para $\beta_2$ $ t=-0,378$, isto é, |t| < $t_{ crit}$, portanto $\beta_2=0$.
#
# Para $\beta_3$ $t=-1,464$, isto é, |t| < $t_{ crit}$, portanto $\beta_3=0$.
#
# Os parâmetros diferentes de zero são $\beta_0$ e $\beta_1$.

# %% [markdown]
# **PERGUNTA 8** 🦄
#
# Na imagem a seguir apresenta-se um mapa com os valores do fator de aumento da variância (VIF) que existe entre as variáveis de um modelo de variáveis múltiplas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ParaTodosVerem Figura que representa um mapa de calor, sendo azul o menor valor (-4) e vermelho escuro o maior (4) valores maiores ou menores do que esses adotaram a cor igual do que o valor extremo definido acima, percorre uma gama de cores de azul, azul claro, cinza, laranja claro, laranja e vermelho. A imagem está representada em forma de matriz $3x3$. As linhas estão organizadas na seguinte ordem: $0,1,2$ (que representam variáveis) e as colunas tem a mesma ordem. Na linha 1 apresentam-se os seguintes valores, $11,04, -1,89, -9,99$, na segunda linha os valores $-1,89, 1,36, 1,05$, na terceira linha os calores $-9,99, 1,5, 10,08$.
#
# Após analisar o gráfico, leia as alternativas sobre a interpretação dele e escolha a correta.

# %% [markdown]
# Não há multicolinearidade devido à presença de valores negativos.
#
# 🧛 **Os valores de 10,8 e 11,04 indicam que existe multicolinearidade.** 🐪
#
# Os valores desse tipo de gráfico devem estar restringidos de -1 a 1.
#
# Os valores de -9,99, 10,8 e 11,04 indicam que existe multicolinearidade.
#
# Como na diagonal tem um valor menor a 4, não se pode afirmar que existe multicolinearidade.

# %% [markdown]
# **Comentário da resposta:**
#
# O gráfico apresenta os resultados do fator de aumento da variância (VIF) que quantifica a multicolinearidade, deve-se prestar atenção na diagonal. Um dos critérios adotados é a existência de multicolinearidade quando existem valores maiores do que $4$, este é o caso de $10,08$ e $11,04$.
